# %% [markdown]
# # Module 1 - Introduction to Pandas
# ## Pandas Part 1

# %% [markdown]
# ### Introduction
#
# ![austin](http://www.austintexas.gov/sites/default/files/aac_logo.jpg)
# You have decided that you want to start your own animal shelter, but you want to get an idea of what that will entail and get more information about planning. You have found out that Austin has one of the largest no-kill animal shelters in the country, and they keep meticulous track of animals that have been taken in and released. However, it is a large file, the online visualization tools provided are terrible, the data is sorted as strings, and the file holds an overwhelming amount  of information. Is there an easy way to look at this data? Can we do this with base Python? Is there a better way?
#
#
# #### _Our goals today are to be able to_: <br/>
#
# - Import/read data using Pandas
# - Identify Pandas objects and manipulate Pandas objects by index and columns
# - Filter data using Pandas
#
# #### _Big questions for this lesson_: <br/>
# - Why use Pandas?
#
#  (a) Provides methods able analyze data stored in the format Data Scientist most often encounter (.csv, .tsv, or .xlsx).
#
#  (b) Makes it very convenient to load, process, and analyze in the aforementioned formats.
#
#  (c) Along with python visualization packages allows for the visual analysis of tabular data.
#
#
# - When do we want to use NumPy versus Pandas?
# - What are the [advantages of using Pandas?](https://stackabuse.com/beginners-tutorial-on-the-pandas-python-library/)
# - What are the [disadvantages of using Pandas?](https://wesmckinney.com/blog/apache-arrow-pandas-internals/)
# - DataFrames are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %% [markdown]
# ### Activation:
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*9IU5fBzJisilYjRAi-f55Q.png" width=600>
#
#
#
#
# - The data manipulation capabilities of Pandas are built on top of the numpy library.
# - Pandas dataframe object represents a spreadsheet with cell values, column names, and row index labels.

# %% [markdown]
# ### 1. Importing and reading data with Pandas!
#
# #### Let's use pandas to read some csv files so we can interact with them.

# %%
# First, let's check which directory we are in so the files we expect to see are there.
# !pwd
# !ls -la
# !ls -la data
# Out:
# /Users/brad/Documents/Scripts/flatiron/dc-ds-100719/module-1/week-1/day-5-pandas-1
# total 56
# drwxr-xr-x  5 brad  staff    160 Oct 11 11:09 .
# drwxr-xr-x  7 brad  staff    224 Oct 11 11:05 ..
# drwxr-xr-x  3 brad  staff     96 Oct 11 11:09 .ipynb_checkpoints
# drwxr-xr-x  4 brad  staff    128 Oct 11 11:05 data
# -rw-r--r--  1 brad  staff  25472 Oct 11 11:09 pandas-1.ipynb
# total 16
# drwxr-xr-x  4 brad  staff  128 Oct 11 11:05 .
# drwxr-xr-x  5 brad  staff  160 Oct 11 11:09 ..
# -rw-r--r--  1 brad  staff   62 Oct 11 11:05 example1.csv
# -rw-r--r--  1 brad  staff  238 Oct 11 11:05 made_up_jobs.csv

# %%
import pandas as pd

example_df = pd.read_csv('data/example1.csv')

# %% [markdown]
# There is also `read_excel`, `read_html`, and many other pandas `read_` functions.
# http://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
example_df.head()
# Out:
#      Title1    Title2    Title3
# 0       one       two     three
# 1  example1  example2  example3

# %% [markdown]
# Try loading in the example file in the `data` directory called `made_up_jobs.csv` using pandas.

# %%
#read in your csv here!
jobs = pd.read_csv('data/made_up_jobs.csv')

#remember that it's nice to be able to look at your data, so let's do that here, too.
jobs.head()
# Out:
#    ID           Name                       Job  Years Employed
# 0   0   Bob Bobberty  Underwater Basket Weaver              13
# 1   1   Susan Smells             Salad Spinner               5
# 2   2  Alex Lastname      Productivity Manager               2
# 3   3        Rudy P.                Being cool              55
# 4   4        Rudy G.  Being compared to Rudy P              50

# %% [markdown]
# You can also load in data by using the url of an associated dataset.

# %%
shelter_data = pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')
# this link is copied directly from the download option for CSV

shelter_data.head()
# Out:
#   Animal ID    Name                DateTime               MonthYear  \
# 0   A806379  Guyute  10/13/2019 03:54:00 PM  10/13/2019 03:54:00 PM
# 1   A797732   Benji  10/13/2019 03:40:00 PM  10/13/2019 03:40:00 PM
# 2   A806428  Akasha  10/13/2019 03:22:00 PM  10/13/2019 03:22:00 PM
# 3   A801936   Snoop  10/13/2019 02:54:00 PM  10/13/2019 02:54:00 PM
# 4   A797476  *Ollie  10/13/2019 02:52:00 PM  10/13/2019 02:52:00 PM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    10/09/2017     Adoption             NaN       Other    Intact Female
# 1    02/17/2019     Adoption             NaN         Dog    Neutered Male
# 2    04/10/2018     Adoption             NaN         Cat    Spayed Female
# 3    02/12/2019     Adoption             NaN         Dog    Neutered Male
# 4    05/05/2019   Euthanasia       Suffering         Cat    Neutered Male
#
#   Age upon Outcome               Breed          Color
# 0          2 years          Guinea Pig       Tricolor
# 1         7 months         Maltese Mix           Buff
# 2           1 year  Domestic Shorthair         Tortie
# 3         7 months            Pit Bull  Brown Brindle
# 4         5 months  Domestic Shorthair          Black

# %% [markdown]
# Now that we can read in data, let's get more comfortable with our Pandas data structures.

# %%
type(shelter_data)

# %%
# Now that data is read let's look at it's shape
print(shelter_data.shape)

# %%
# What are the names of the columns
print(shelter_data.columns)

# %%
# What are the different data types present in our data
print(shelter_data.info())

# %%
# We can find the type of a particular columns in a data frame in this way.
ID_series = shelter_data['Animal ID']
shelter_data['Animal ID'].dtypes
shelter_data.rename(columns={'size': 'Name'}, inplace=True)
shelter_data.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %% [markdown]
# ### 2. Utilizing and identifying Pandas objects
#
# - What is a DataFrame object and what is a Series object?
# - How are they different from Python lists?
#
# These are questions we will cover in this section. To start, let's start with this list of fruits.

# %%
fruits = ['Apple', 'Orange', 'Watermelon', 'Lemon', 'Mango']

print(fruits)
# Out:
# ['Apple', 'Orange', 'Watermelon', 'Lemon', 'Mango']

# %% [markdown]
# Using our list of fruits, we can create a pandas object called a 'series' which is much like an array or a vector.

# %%
fruits_series = pd.Series(fruits)

print(fruits_series)
type(fruits_series)
# Out:
# 0         Apple
# 1        Orange
# 2    Watermelon
# 3         Lemon
# 4         Mango
# dtype: object
# pandas.core.series.Series

# %% [markdown]
# One difference between python **list objects** and pandas **series objects** is the fact that you can define the index manually for a **series objects**.

# %%
ind = ['a', 'b', 'c', 'd', 'e']

fruits_series = pd.Series(fruits, index=ind)

print(fruits_series)
# Out:
# a         Apple
# b        Orange
# c    Watermelon
# d         Lemon
# e         Mango
# dtype: object

# %% [markdown]
# With a partner, create your own custom series from a list of lists.

# %%
list_of_lists = [['cat','ape'], ['dog'], ['horse'], ['cow'], ['macaw']]

lst = [x for sublist in list_of_lists for x in sublist]
print(lst)
# create custom indices for your series
# ind = ['imagine that','what a hog','she died of course','dunno how','how absurd']
ind = range(2,7)
# create the series using your list objects
# You can use either a for loop or also pd.Series
list_of_lists_series = pd.Series(list_of_lists, index=ind)

# print your series
print(list_of_lists_series)
type(list_of_lists_series)
# Out:
# ['cat', 'ape', 'dog', 'horse', 'cow', 'macaw']
# 2    [cat, ape]
# 3         [dog]
# 4       [horse]
# 5         [cow]
# 6       [macaw]
# dtype: object
# pandas.core.series.Series

# %% [markdown]
# We can do a simliar thing with Python dictionaries. This time, however, we will create a DataFrame object from a python dictionary.

# %%
# Dictionary with list object in values
student_dict = {
    'name': ['Samantha', 'Alex', 'Dante'],
    'age': ['35', '17', '26'],
    'city': ['Houston', 'Seattle', 'New york']
}

students_df = pd.DataFrame(student_dict)

students_df.head()
# Out:
#        name age      city
# 0  Samantha  35   Houston
# 1      Alex  17   Seattle
# 2     Dante  26  New york

# %%
#to find data types of columns
students_df.dtypes
# Out:
# name    object
# age     object
# city    object
# dtype: object

# %% [markdown]
# Let's change the data type of ages to int.

# %%
# We can also change a columns type but the change has to make sense.
students_df.age = students_df.age.astype(int)

#Uncomment line below and observe what happens when trying to convert student's name to int or float
students_df.name = students_df.name.astype(int)


#How about what happens converting numeric to string
#students_df.age = students_df.age.astype(str)

students_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f8777d2015e1> in <module>()
#       3
#       4 #Uncomment line below and observe what happens when trying to convert student's name to int or float
# ----> 5 students_df.name = students_df.name.astype(int)
#       6
#       7
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# /usr/local/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: 'Samantha'

# %% [markdown]
# We can also use a custom index for these items. For example, we might want them to be the individual student ID numbers.

# %%
school_ids = ['1111', '1145', '0096']

# Notice here we use pd.DataFrame not pd.Series as we did for a pandas series.
students_df = pd.DataFrame(student_dict, index=school_ids)

students_df.head()

# %% [markdown]
# Using Pandas, we can also rename column names.

# %%
students_df.columns = ['NAME', 'AGE', 'HOME']
students_df.head()

# %% [markdown]
# Or, we can also change the column names using the rename function.

# %%
students_df.rename(columns={'AGE': 'YEARS'})

# %%
# Notice what happens when we print students_df

students_df

# %%
# If you want the file to save over itself, use the option `inplace = True`.
students_df.rename(columns={'AGE': 'YEARS'}, inplace=True)
students_df.head()

# %% [markdown]
# Similarly, there is a tool to remove rows and columns from your DataFrame

# %%
students_df.drop(columns=['YEARS', 'HOME'])

# %%
#Notice again what happens if we print students_df 
students_df

# %%
students_df.drop(columns=['YEARS', 'HOME'], inplace=True)
students_df

# %% [markdown]
# If you want the file to save over itself, use the option `inplace = True`.
#
# Every function has options. Let's read more about `drop` [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %% [markdown]
# ### 3. Filtering Data Using Pandas
# There are several ways to grab particular data from a DataFrame.
# - Python lists allow for selection of data only through integer location.
# - You can use a single integer or slice notation to make the selection but NOT a list of integers.
# - Dictionaries only allow selection with a single label. Slices and lists of labels are not allowed.

# %%
l = [1, 2, 3, 4, 5]
l[[0, 5]]

# %% [markdown]
# ### DataFrames can be indexed by column name (label) or row name (index) or by position.
# #### The `.loc` method is used for indexing by name.
# #### While `.iloc` is used for indexing by number.

# %%
student_dict = {
    'name': ['Samantha', 'Alex', 'Dante'],
    'age': ['35', '17', '26'],
    'city': ['Houston', 'Seattle', 'New york']
}

students_df = pd.DataFrame(student_dict)

# %%
students_df

# %% [markdown]
# ### Let's take a look at `.iloc`
# #### `.iloc` takes slices based on index position.
# #### `.iloc` stands for integer location so that should help with remember what it does
# #### `.iloc`[row , column]

# %%
# returns the first row
students_df.iloc[0]

# %%
# returns the first column
students_df.iloc[:, 0]

# %%
# returns first two rows notice that ILOC performs regular python slicing.
students_df.iloc[0:2]

# %%
# returns the first two columns
students_df.iloc[:, 0:2]

# %%
# returns first row and columns 1 and 2
students_df.iloc[0:1, 0:2]

# %% [markdown]
# ### How would we use `.iloc` to return the last item in the last row?

# %%
# return the last item in the last row using iloc
students_df.iloc[-1,-1]
# Out:
# 'New york'

# %% [markdown]
# ### How would we use `.iloc` to return the first item in the last column?

# %%
# return the last item in the last column using iloc
students_df.iloc[0,-1]
# Out:
# 'Houston'

# %% [markdown]
# ### What if we only want certain columns or rows?

# %%
# Don't do students_df.iloc[0, 2]
students_df.iloc[[0, 2]]
# Out:
#        name  age      city
# 0  Samantha   35   Houston
# 2     Dante   26  New york

# %%
students_df.iloc[[0, 2], [0, 2]]
# Out:
#        name      city
# 0  Samantha   Houston
# 2     Dante  New york

# %% [markdown]
# ### Let's take a look at `.loc`
# #### Label based method.
# #### Names or labels of the index is used when taking slices.
# #### Also supports boolean subsetting.

# %%
# We will use loc to return rows and columns based on labels. Let's look at the students_df DataFrame again.
students_df

# %%
# returns the student information associated with index 0
students_df.loc[0]

# %%
# returns the student information for row index 0 to 2 inclusive.
# note iloc would return normal python slicing not including 2 as demonstrated above.
students_df.loc[0:2]

# %%
# returns the column labeled 'age'
students_df.loc[:, 'age']

# %%
# returns the column labeled 'age' and index values 1 to 2.
# gives us the values of the rows with index from 1 to 2 (inclusive)
# and columns labeled age"
students_df.loc[1:2, 'age']

# %%
# returns the column labeled 'age' and index values 1 to 2.
# gives us the values of the rows with index from 1 to 2 (inclusive)
# and columns labeled age to city (inclusive)"
students_df.loc[1:2, 'age':'city']

# %%
# What should we get?
students_df.loc[1:2, ['name', 'city']]

# %%
# How about?
students_df.loc[[0, 2], ['name', 'city']]

# %%
# if index rearranged
school_ids = ['5', '11', '3']
students_df = pd.DataFrame(student_dict, index=school_ids)

# %%
students_df

# %%
# What should we get now?
students_df.loc[[0, 2], ['name', 'city']]

# %%
# What should we get now?
students_df.loc[['5', '11'], ['name', 'city']]

# %%
students_df.set_index("name", inplace=True)
students_df

# %%
students_df.loc[['Samantha']]

# %%
# Subsetting nonconsecutive rows
students_df.loc[['Samantha', 'Dante']]

# %%
# Samantha to the end
students_df.loc['Samantha':]

# %%
# return the first and last rows using one loc command

# %% [markdown]
# ### Boolean Subsetting

# %%
student_dict = {
    'name': ['Samantha', 'Alex', 'Dante', 'Samantha'],
    'age': ['35', '17', '26', '21'],
    'city': ['Houston', 'Seattle', 'New york', 'Atlanta'],
    'state': ['Texas', 'Washington', 'New York', 'Georgia']
}

students_df = pd.DataFrame(student_dict)

# %%
# The statement data[‘name’] == ‘Samantha’] produces a Pandas Series with a True/False value for every row
# in the ‘data’ DataFrame, where there are “True” values for the rows where the name is “Samantha”.
# These type of boolean arrays can be passed directly to the .loc indexer.
students_df.loc[students_df['name'] == 'Samantha']

# %%
# What about if we only want the city and state of the selected students with the name Samantha?
students_df.loc[students_df['name'] == 'Samantha', ['city', 'state']]

# %%
# What amount if we want to select a student of a specific age?
students_df.loc[students_df['age'] == '21']

# %%
# What amount if we want to select a student of a specific age?
students_df.loc[(students_df['age'] == '21') &
                (students_df['city'] == 'Atlanta')]

# %%
# What should be returned?
students_df.loc[(students_df['age'] == '35') &
                (students_df['city'] == 'Atlanta')]

# %% [markdown]
# ### Lesson Recap
# Pandas combines the power of python lists (selection via integer location) and dictionaries (selection by label)
#
# `.iloc` is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# `.iloc` will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing (this conforms with python/numpy slice semantics).
#
# `.loc` is primarily label based, but may also be used with a boolean array.
#
# #### Warning Note that contrary to usual python slices, both the start and the stop are included.
#
# `.loc` will raise a keyError when any items are not found.
#
# ### Pandas
# - The data structures in Pandas are implemented using series and dataframe classes.
# - A series is a one-dimensional indexed array of some fixed data type.
# - While a dataframe is a two-dimensional data structure like a table where each column contains data of the same type.
# - DataFrames are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %% [markdown]
# ### CLASS ASSIGNMENT
# Now that we have all of these new tools in our tool belt, use these tools on the shelter data set!
# - Use `shelter_data.columns` to get the list of column names.
# - Subset the data by '`Outcome Subtype`.
# - Subset the data by '`Outcome Subtype` `Adoption` and only return the `Animal Type` column.
# - Subset the data by '`Outcome Subtype` `Adoption` and only return the `Animal Type` column with only `Cat`.
# - Play around with your new tools on the data set.
# - For extra credit: What are the data types returned from the different subsetting? Is what returned a series or dataframe?

# %%
import pandas as pd
shelter_data = pd.read_csv(
    'https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')
shelter_data.head()
# Out:
#   Animal ID      Name                DateTime               MonthYear  \
# 0   A800276  Porkchop  10/10/2019 07:30:00 PM  10/10/2019 07:30:00 PM
# 1   A806032       NaN  10/10/2019 06:25:00 PM  10/10/2019 06:25:00 PM
# 2   A806431       NaN  10/10/2019 06:13:00 PM  10/10/2019 06:13:00 PM
# 3   A806432       NaN  10/10/2019 06:13:00 PM  10/10/2019 06:13:00 PM
# 4   A806149  *Bingley  10/10/2019 05:59:00 PM  10/10/2019 05:59:00 PM
#
#   Date of Birth     Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    09/19/2004  Return to Owner             NaN         Dog      Intact Male
# 1    07/21/2019         Adoption             NaN         Cat    Intact Female
# 2    09/18/2019         Transfer         Partner         Cat          Unknown
# 3    09/18/2019         Transfer         Partner         Cat          Unknown
# 4    10/06/2017         Adoption             NaN         Dog    Neutered Male
#
#   Age upon Outcome                                   Breed              Color
# 0         15 years                   Australian Cattle Dog                Tan
# 1         2 months                      Domestic Shorthair        Black/White
# 2          3 weeks                      Domestic Shorthair              Black
# 3          3 weeks                      Domestic Shorthair        Brown Tabby
# 4          2 years  Basset Hound/American Pit Bull Terrier  Brown Tiger/White

# %%
shelter_data.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
# 27        08/02/2019     Adoption             NaN         Cat
# 28        09/10/2017     Adoption             NaN         Cat
# 31        10/07/2017     Adoption             NaN         Cat
# 32        06/01/2019     Adoption          Foster         Cat
# 33        05/28/2019     Adoption             NaN         Cat
# 35        04/04/2019     Adoption             NaN         Dog
# 37        05/07/2019     Adoption             NaN         Dog
# 38        09/13/2017     Adoption             NaN         Dog
# 39        08/05/2018     Adoption             NaN         Dog
# 40        06/07/2019     Adoption             NaN         Cat
# 41        07/21/2019     Adoption             NaN         Cat
# 42        07/30/2019     Adoption             NaN         Cat
# 43        10/03/2014     Adoption             NaN         Dog
# 44        10/10/2012     Adoption             NaN         Dog
# 55        10/18/2016     Adoption             NaN         Dog
# 61        12/17/2017     Adoption             NaN         Dog
# 62        07/11/2018     Adoption             NaN         Cat
# ...              ...          ...             ...         ...
# 109287    06/21/2013     Adoption             NaN         Cat
# 109289    07/08/2011     Adoption          Foster         Cat
# 109294    06/18/2013     Adoption          Foster         Dog
# 109311    01/15/2012     Adoption             NaN         Cat
# 109314    01/14/2013     Adoption             NaN         Dog
# 109316    07/27/2013     Adoption             NaN         Dog
# 109319    09/25/2011     Adoption             NaN         Dog
# 109320    09/27/2009     Adoption             NaN         Dog
# 109322    10/27/2012     Adoption             NaN         Dog
# 109323    06/08/2012     Adoption             NaN         Dog
# 109327    10/31/2011     Adoption             NaN         Dog
# 109328    07/18/2013     Adoption             NaN         Cat
# 109342    03/25/2012     Adoption             NaN         Dog
# 109345    07/07/2013     Adoption          Foster         Cat
# 109355    09/25/2011     Adoption             NaN         Dog
# 109356    08/11/2011     Adoption             NaN         Dog
# 109357    09/24/2011     Adoption             NaN         Dog
# 109359    05/12/2013     Adoption             NaN         Cat
# 109368    06/24/2013     Adoption          Foster         Dog
# 109370    04/01/2013     Adoption             NaN         Cat
# 109373    07/27/2013     Adoption             NaN         Dog
# 109377    07/27/2013     Adoption             NaN         Dog
# 109378    01/29/2013     Adoption             NaN         Dog
# 109379    07/19/2013     Adoption             NaN         Cat
# 109382    07/09/2013     Adoption             NaN         Cat
# 109387    08/29/2010     Adoption             NaN         Dog
# 109410    04/22/2013     Adoption             NaN         Cat
# 109411    03/25/2013     Adoption             NaN         Cat
# 109413    09/21/2010     Adoption             NaN         Dog
# 109420    07/23/2013     Adoption          Foster         Dog
#
#        Sex upon Outcome Age upon Outcome                               Breed  \
# 0         Intact Female          2 years                          Guinea Pig
# 1         Neutered Male         7 months                         Maltese Mix
# 2         Spayed Female           1 year                  Domestic Shorthair
# 3         Neutered Male         7 months                            Pit Bull
# 6         Spayed Female         6 months              Labrador Retriever Mix
# 10        Spayed Female          1 month           Australian Cattle Dog Mix
# 11        Spayed Female          2 years                         Pointer Mix
# 13        Neutered Male          2 years                    Basenji/Pit Bull
# 14        Neutered Male          2 years              Domestic Shorthair Mix
# 18        Intact Female          1 month                  Domestic Shorthair
# 19        Spayed Female          2 years                      Siberian Husky
# 20        Neutered Male         7 months                 German Shepherd Mix
# 26        Neutered Male         3 months              Domestic Shorthair Mix
# 27        Neutered Male         2 months                  Domestic Shorthair
# 28        Neutered Male          2 years                  Domestic Shorthair
# 44              White/Black
# 55      Brown Brindle/White
# 61              Black/White
# 62               Blue/White
# ...                     ...
# 109287          Black/White
# 109289         Orange Tabby
# 109294           Blue/White
# 109311           Blue/White
# 109314          Black/White
# 109316            Tan/White
# 109319                Black
# 109320             Tricolor
# 109322                 Buff
# 109323                Black
# 109327         Silver/Brown
# 109328         Orange Tabby
# 109342          Black/White
# 109345          Lilac Point
# 109355            Black/Tan
# 109356                  Tan
# 109357  Brown Brindle/White
# 109359    Brown Tabby/White
# 109368          Black/White
# 109370     Blue Tabby/White
# 109373            Black/Tan
# 109377            Black/Tan
# 109378                Brown
# 109379           Blue Point
# 109382           Blue/White
# 109387          Black/White
# 109410                Black
# 109411               Tortie
# 109413          White/Brown
# 109420                Black
#
# [47642 rows x 12 columns]

# %%
shelter_data[shelter_data['Outcome Type'] == "Adoption"]['Animal Type']
# Out:
# 0         Other
# 1           Dog
# 2           Cat
# 3           Dog
# 6           Dog
# 10          Dog
# 11          Dog
# 13          Dog
# 14          Cat
# 18          Cat
# 19          Dog
# 20          Dog
# 26          Cat
# 27          Cat
# 28          Cat
# 31          Cat
# 32          Cat
# 33          Cat
# 35          Dog
# 37          Dog
# 38          Dog
# 39          Dog
# 40          Cat
# 41          Cat
# 42          Cat
# 43          Dog
# 44          Dog
# 55          Dog
# 61          Dog
# 62          Cat
#           ...
# 109287      Cat
# 109289      Cat
# 109294      Dog
# 109311      Cat
# 109314      Dog
# 109316      Dog
# 109319      Dog
# 109320      Dog
# 109322      Dog
# 109323      Dog
# 109327      Dog
# 109328      Cat
# 109342      Dog
# 109345      Cat
# 109355      Dog
# 109356      Dog
# 109357      Dog
# 109359      Cat
# 109368      Dog
# 109370      Cat
# 109373      Dog
# 109377      Dog
# 109378      Dog
# 109379      Cat
# 109382      Cat
# 109387      Dog
# 109410      Cat
# 109411      Cat
# 109413      Dog
# 109420      Dog
# Name: Animal Type, Length: 47642, dtype: object

# %%
shelter_data[(shelter_data['Outcome Type'] == "Adoption") & (shelter_data['Animal Type'] == "Cat")]['Animal Type']
# Out:
# 2         Cat
# 14        Cat
# 18        Cat
# 26        Cat
# 27        Cat
# 28        Cat
# 31        Cat
# 32        Cat
# 33        Cat
# 40        Cat
# 41        Cat
# 42        Cat
# 62        Cat
# 63        Cat
# 65        Cat
# 70        Cat
# 71        Cat
# 78        Cat
# 79        Cat
# 85        Cat
# 89        Cat
# 93        Cat
# 105       Cat
# 106       Cat
# 109       Cat
# 110       Cat
# 117       Cat
# 123       Cat
# 124       Cat
# 125       Cat
#          ...
# 109174    Cat
# 109176    Cat
# 109182    Cat
# 109189    Cat
# 109194    Cat
# 109195    Cat
# 109202    Cat
# 109207    Cat
# 109210    Cat
# 109214    Cat
# 109215    Cat
# 109216    Cat
# 109218    Cat
# 109255    Cat
# 109259    Cat
# 109261    Cat
# 109263    Cat
# 109265    Cat
# 109275    Cat
# 109287    Cat
# 109289    Cat
# 109311    Cat
# 109328    Cat
# 109345    Cat
# 109359    Cat
# 109370    Cat
# 109379    Cat
# 109382    Cat
# 109410    Cat
# 109411    Cat
# Name: Animal Type, Length: 18250, dtype: object
