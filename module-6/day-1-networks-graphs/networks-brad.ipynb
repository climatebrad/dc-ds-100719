# %% [markdown]
# ## Why Networks?
#
# * Great at modeling relationships
# * Social Networks
# * Transportation Networks

# %% [markdown]
# <img src = "./resources/graph.png" style="width: 300px;">

# %% [markdown]
# ## Components of Graphs
#
# * Nodes
# * Edges (weighted/unweighted and directed/undirected)
# * Degree
#
# #### Examples of Graphs
#
# * Undirected / Directed Graph
# <img src="./resources/Directed_graph.jpg" width="600">
# * Bipartite Graph
# <img src="./resources/bipartite.png">

# %% [markdown]
# ### Moving through graphs
#
# * path : the route from one node to another
# * shortest path: the shortest possible route from one to another

# %% [markdown]
# ## Node Centrality
#
# * **Degree Centrality**: How many connections does a node have?
#
#
# ## $$\frac{\#\ of\ neighbors\ a\ node\ has}{\#\ of\ neighbors\ it\ could\ possibly\ have}$$
#
# <img src="./resources/centrality.png">
#
#
# ---

# %% [markdown]
#  * **Betweenness Centrality**: How important is an individual node to a network? Captures bottlenecks
#
#
# <img  src ="./resources/betweenness_formula.svg">
#
#
# where $\sigma_{st}$ is the total number of shortest paths from node *s* to node *t* and $\sigma_{st}(v)$ is the number of paths that pass through v
#
#
#
# ## $$\frac{\#\ of\ shortest\ paths\ moving\ from\ one\ node\ to\ another\ including \ node\ of\ interest}{\#\ all\ possible\ shortest\ paths\ from\ one\ node\ to\ another}$$
#
# <img src="./resources/betweenness.png" width="400">
# ---

# %% [markdown]
# * **Closeness Centrality**:  Calculated as the reciprocal of the sum of the length of the shortest paths between the node and all other nodes in the graph. Thus, the more central a node is, the closer it is to all other nodes.
#
# <img src ="./resources/closeness.svg">
# where $\displaystyle d(y,x)$ $\displaystyle d(y,x)$ is the distance between vertices $\displaystyle x$ and $\displaystyle y$
#
# <img src="./resources/closeness.png" width="400">
# https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0165781

# %%
# Let's try all this in code
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from operator import itemgetter
# %matplotlib inline

# %%
book1_df = pd.read_csv('./resources/asiof/asoiaf-book1-edges.csv')
g1 = nx.Graph()
for row in book1_df.iterrows():
    g1.add_edge(row[1]['Source'], row[1]['Target'],
                weight=row[1]['weight'], book=row[1]['book'])

# see all of the nodes
g1.nodes()
# Out:
# NodeView(('Addam-Marbrand', 'Jaime-Lannister', 'Tywin-Lannister', 'Aegon-I-Targaryen', 'Daenerys-Targaryen', 'Eddard-Stark', 'Aemon-Targaryen-(Maester-Aemon)', 'Alliser-Thorne', 'Bowen-Marsh', 'Chett', 'Clydas', 'Jeor-Mormont', 'Jon-Snow', 'Samwell-Tarly', 'Aerys-II-Targaryen', 'Brandon-Stark', 'Gerold-Hightower', 'Jon-Arryn', 'Robert-Baratheon', 'Aggo', 'Drogo', 'Jhogo', 'Jorah-Mormont', 'Quaro', 'Rakharo', 'Albett', 'Halder', 'Rast', 'Grenn', 'Pypar', 'Tyrion-Lannister', 'Alyn', 'Harwin', 'Jory-Cassel', 'Tomard', 'Arthur-Dayne', 'Arya-Stark', 'Benjen-Stark', 'Bran-Stark', 'Catelyn-Stark', 'Cersei-Lannister', 'Desmond', 'Ilyn-Payne', 'Jeyne-Poole', 'Joffrey-Baratheon', 'Meryn-Trant', 'Mordane', 'Mycah', 'Myrcella-Baratheon', 'Petyr-Baelish', 'Rickon-Stark', 'Robb-Stark', 'Rodrik-Cassel', 'Sandor-Clegane', 'Sansa-Stark', 'Syrio-Forel', 'Tommen-Baratheon', 'Vayon-Poole', 'Yoren', 'Arys-Oakheart', 'Balon-Greyjoy', 'Balon-Swann', 'Renly-Baratheon', 'Barristan-Selmy', 'Boros-Blount', 'Pycelle', 'Varys', 'Jaremy-Rykker', 'Luwin', 'Mance-Rayder', 'Theon-Greyjoy', 'Waymar-Royce', 'Beric-Dondarrion', 'Gregor-Clegane', 'Loras-Tyrell', 'Thoros-of-Myr', 'Hali', 'Hallis-Mollen', 'Hodor', 'Hullen', 'Joseth', 'Nan', 'Osha', 'Rickard-Karstark', 'Rickard-Stark', 'Stiv', 'Lyanna-Stark', 'Bronn', 'Chiggen', 'Marillion', 'Shae', 'Shagga', 'Vardis-Egen', 'Willis-Wode', 'Brynden-Tully', 'Edmure-Tully', 'Hoster-Tully', 'Lysa-Arryn', 'Nestor-Royce', 'Walder-Frey', 'Colemon', 'Donnel-Waynwood', 'Eon-Hunter', 'Jon-Umber-(Greatjon)', 'Masha-Heddle', 'Moreo-Tumitis', 'Mya-Stone', 'Mychel-Redfort', 'Robert-Arryn', 'Stevron-Frey', 'Tytos-Blackwood', 'Wendel-Manderly', 'Cayn', 'Janos-Slynt', 'Stannis-Baratheon', 'Chella', 'Clement-Piper', 'Karyl-Vance', 'Cohollo', 'Haggo', 'Qotho', 'Conn', 'Coratt', 'Doreah', 'Eroeh', 'Illyrio-Mopatis', 'Irri', 'Jhiqui', 'Mirri-Maz-Duur', 'Rhaegar-Targaryen', 'Viserys-Targaryen', 'Danwell-Frey', 'Hosteen-Frey', 'Jared-Frey', 'Dareon', 'Daryn-Hornwood', 'Torrhen-Karstark', 'Dolf', 'Donal-Noye', 'Jommo', 'Ogo', 'Rhaego', 'Dywen', 'Galbart-Glover', 'Gendry', 'High-Septon-(fat_one)', 'Howland-Reed', 'Jacks', 'Joss', 'Marq-Piper', 'Porther', 'Raymun-Darry', 'Tobho-Mott', 'Tregar', 'Varly', 'Wyl-(guard)', 'Wylla', 'Fogo', 'Roose-Bolton', 'Gared', 'Will-(prologue)', 'Oswell-Whent', 'Todder', 'Gunthor-son-of-Gurn', 'Harys-Swyft', 'Heward', 'Hobb', 'Hugh', 'Jafer-Flowers', 'Kevan-Lannister', 'Matthar', 'Othor', 'Maege-Mormont', 'Jonos-Bracken', 'Jyck', 'Morrec', 'Kurleket', 'Lancel-Lannister', 'Leo-Lefford', 'Mace-Tyrell', 'Lyn-Corbray', 'Paxter-Redwyne', 'Maegor-I-Targaryen', 'Mord', 'Randyll-Tarly', 'Timett', 'Ulf-son-of-Umar'))

# %%
# see all of the edges
g1.edges()
# Out:
# EdgeView([('Addam-Marbrand', 'Jaime-Lannister'), ('Addam-Marbrand', 'Tywin-Lannister'), ('Jaime-Lannister', 'Aerys-II-Targaryen'), ('Jaime-Lannister', 'Barristan-Selmy'), ('Jaime-Lannister', 'Brynden-Tully'), ('Jaime-Lannister', 'Catelyn-Stark'), ('Jaime-Lannister', 'Cersei-Lannister'), ('Jaime-Lannister', 'Eddard-Stark'), ('Jaime-Lannister', 'Edmure-Tully'), ('Jaime-Lannister', 'Galbart-Glover'), ('Jaime-Lannister', 'Gregor-Clegane'), ('Jaime-Lannister', 'Harys-Swyft'), ('Jaime-Lannister', 'Joffrey-Baratheon'), ('Jaime-Lannister', 'Jon-Arryn'), ('Jaime-Lannister', 'Jory-Cassel'), ('Jaime-Lannister', 'Kevan-Lannister'), ('Jaime-Lannister', 'Loras-Tyrell'), ('Jaime-Lannister', 'Lysa-Arryn'), ('Jaime-Lannister', 'Petyr-Baelish'), ('Jaime-Lannister', 'Renly-Baratheon'), ('Jaime-Lannister', 'Rickard-Karstark'), ('Jaime-Lannister', 'Robb-Stark'), ('Jaime-Lannister', 'Robert-Baratheon'), ('Jaime-Lannister', 'Rodrik-Cassel'), ('Jaime-Lannister', 'Sandor-Clegane'), ('Jaime-Lannister', 'Sansa-Stark'), ('Jaime-Lannister', 'Tyrion-Lannister'), ('Jaime-Lannister', 'Tywin-Lannister'), ('Jaime-Lannister', 'Varys'), ('Jaime-Lannister', 'Wyl-(guard)'), ('Tywin-Lannister', 'Bronn'), ('Tywin-Lannister', 'Brynden-Tully'), ('Tywin-Lannister', 'Catelyn-Stark'), ('Tywin-Lannister', 'Cersei-Lannister'), ('Tywin-Lannister', 'Eddard-Stark'), ('Tywin-Lannister', 'Gregor-Clegane'), ('Tywin-Lannister', 'Joffrey-Baratheon'), ('Tywin-Lannister', 'Jon-Umber-(Greatjon)'), ('Tywin-Lannister', 'Kevan-Lannister'), ('Tywin-Lannister', 'Marq-Piper'), ('Tywin-Lannister', 'Pycelle'), ('Tywin-Lannister', 'Rhaegar-Targaryen'), ('Tywin-Lannister', 'Robb-Stark'), ('Tywin-Lannister', 'Robert-Baratheon'), ('Tywin-Lannister', 'Roose-Bolton'), ('Tywin-Lannister', 'Stannis-Baratheon'), ('Tywin-Lannister', 'Theon-Greyjoy'), ('Tywin-Lannister', 'Tyrion-Lannister'), ('Tywin-Lannister', 'Varys'), ('Tywin-Lannister', 'Walder-Frey'), ('Aegon-I-Targaryen', 'Daenerys-Targaryen'), ('Aegon-I-Targaryen', 'Eddard-Stark'), ('Daenerys-Targaryen', 'Aggo'), ('Daenerys-Targaryen', 'Cohollo'), ('Daenerys-Targaryen', 'Doreah'), ('Daenerys-Targaryen', 'Drogo'), ('Daenerys-Targaryen', 'Eddard-Stark'), ('Daenerys-Targaryen', 'Eroeh'), ('Daenerys-Targaryen', 'Haggo'), ('Daenerys-Targaryen', 'Illyrio-Mopatis'), ('Daenerys-Targaryen', 'Irri'), ('Daenerys-Targaryen', 'Jhiqui'), ('Daenerys-Targaryen', 'Jhogo'), ('Daenerys-Targaryen', 'Jorah-Mormont'), ('Daenerys-Targaryen', 'Mirri-Maz-Duur'), ('Daenerys-Targaryen', 'Qotho'), ('Daenerys-Targaryen', 'Quaro'), ('Daenerys-Targaryen', 'Rakharo'), ('Daenerys-Targaryen', 'Rhaegar-Targaryen'), ('Daenerys-Targaryen', 'Robert-Baratheon'), ('Daenerys-Targaryen', 'Varys'), ('Daenerys-Targaryen', 'Viserys-Targaryen'), ('Eddard-Stark', 'Aerys-II-Targaryen'), ('Eddard-Stark', 'Alyn'), ('Eddard-Stark', 'Arya-Stark'), ('Eddard-Stark', 'Balon-Greyjoy'), ('Eddard-Stark', 'Barristan-Selmy'), ('Eddard-Stark', 'Beric-Dondarrion'), ('Eddard-Stark', 'Bran-Stark'), ('Eddard-Stark', 'Brandon-Stark'), ('Eddard-Stark', 'Catelyn-Stark'), ('Eddard-Stark', 'Cayn'), ('Eddard-Stark', 'Cersei-Lannister'), ('Eddard-Stark', 'Daryn-Hornwood'), ('Eddard-Stark', 'Desmond'), ('Eddard-Stark', 'Edmure-Tully'), ('Eddard-Stark', 'Galbart-Glover'), ('Eddard-Stark', 'Gendry'), ('Eddard-Stark', 'Gerold-Hightower'), ('Eddard-Stark', 'Gregor-Clegane'), ('Eddard-Stark', 'Harwin'), ('Eddard-Stark', 'High-Septon-(fat_one)'), ('Eddard-Stark', 'Howland-Reed'), ('Eddard-Stark', 'Ilyn-Payne'), ('Eddard-Stark', 'Jacks'), ('Eddard-Stark', 'Janos-Slynt'), ('Eddard-Stark', 'Joffrey-Baratheon'), ('Eddard-Stark', 'Jon-Arryn'), ('Eddard-Stark', 'Jon-Snow'), ('Eddard-Stark', 'Jory-Cassel'), ('Eddard-Stark', 'Joss'), ('Eddard-Stark', 'Loras-Tyrell'), ('Eddard-Stark', 'Luwin'), ('Eddard-Stark', 'Lyanna-Stark'), ('Eddard-Stark', 'Lysa-Arryn'), ('Eddard-Stark', 'Marq-Piper'), ('Eddard-Stark', 'Mordane'), ('Eddard-Stark', 'Mycah'), ('Eddard-Stark', 'Petyr-Baelish'), ('Eddard-Stark', 'Porther'), ('Eddard-Stark', 'Pycel ...

# %%
# find neighbors of Tyrion Lannister
[x for x in g1.neighbors('Tyrion-Lannister')]
# Out:
# ['Alliser-Thorne',
#  'Benjen-Stark',
#  'Bran-Stark',
#  'Bronn',
#  'Brynden-Tully',
#  'Catelyn-Stark',
#  'Cersei-Lannister',
#  'Chella',
#  'Chiggen',
#  'Conn',
#  'Eddard-Stark',
#  'Gregor-Clegane',
#  'Gunthor-son-of-Gurn',
#  'Jaime-Lannister',
#  'Jeor-Mormont',
#  'Joffrey-Baratheon',
#  'Jon-Arryn',
#  'Jon-Snow',
#  'Jyck',
#  'Kevan-Lannister',
#  'Kurleket',
#  'Leo-Lefford',
#  'Luwin',
#  'Lysa-Arryn',
#  'Marillion',
#  'Mord',
#  'Morrec',
#  'Petyr-Baelish',
#  'Renly-Baratheon',
#  'Rickon-Stark',
#  'Robb-Stark',
#  'Robert-Arryn',
#  'Robert-Baratheon',
#  'Rodrik-Cassel',
#  'Sandor-Clegane',
#  'Sansa-Stark',
#  'Shae',
#  'Shagga',
#  'Theon-Greyjoy',
#  'Timett',
#  'Tommen-Baratheon',
#  'Tywin-Lannister',
#  'Vardis-Egen',
#  'Varys',
#  'Willis-Wode',
#  'Yoren']

# %%
# degree centrality
nx.degree_centrality(g1)
# Out:
# {'Addam-Marbrand': 0.010752688172043012,
#  'Jaime-Lannister': 0.15591397849462366,
#  'Tywin-Lannister': 0.11827956989247312,
#  'Aegon-I-Targaryen': 0.010752688172043012,
#  'Daenerys-Targaryen': 0.11290322580645162,
#  'Eddard-Stark': 0.3548387096774194,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.03763440860215054,
#  'Alliser-Thorne': 0.05376344086021506,
#  'Bowen-Marsh': 0.02688172043010753,
#  'Chett': 0.016129032258064516,
#  'Clydas': 0.005376344086021506,
#  'Jeor-Mormont': 0.06989247311827958,
#  'Jon-Snow': 0.19892473118279572,
#  'Samwell-Tarly': 0.06451612903225806,
#  'Aerys-II-Targaryen': 0.03225806451612903,
#  'Brandon-Stark': 0.03225806451612903,
#  'Gerold-Hightower': 0.02688172043010753,
#  'Jon-Arryn': 0.08064516129032259,
#  'Robert-Baratheon': 0.2688172043010753,
#  'Aggo': 0.03225806451612903,
#  'Drogo': 0.10215053763440861,
#  'Jhogo': 0.03225806451612903,
#  'Jorah-Mormont': 0.06989247311827958,
#  'Quaro': 0.02688172043010753,
#  'Rakharo': 0.02688172043010753,
#  'Albett': 0.016129032258064516,
#  'Halder': 0.043010752688172046,
#  'Rast': 0.03225806451612903,
#  'Grenn': 0.03763440860215054,
#  'Pypar': 0.03763440860215054,
#  'Tyrion-Lannister': 0.24731182795698928,
#  'Alyn': 0.02688172043010753,
#  'Harwin': 0.021505376344086023,
#  'Jory-Cassel': 0.11290322580645162,
#  'Tomard': 0.03763440860215054,
#  'Arthur-Dayne': 0.005376344086021506,
#  'Arya-Stark': 0.14516129032258066,
#  'Benjen-Stark': 0.07526881720430108,
#  'Bran-Stark': 0.17204301075268819,
#  'Catelyn-Stark': 0.23118279569892475,
#  'Cersei-Lannister': 0.16129032258064518,
#  'Desmond': 0.010752688172043012,
#  'Ilyn-Payne': 0.048387096774193554,
#  'Jeyne-Poole': 0.03225806451612903,
#  'Joffrey-Baratheon': 0.16129032258064518,
#  'Meryn-Trant': 0.048387096774193554,
#  'Mordane': 0.05913978494623656,
#  'Mycah': 0.02688172043010753,
#  'Myrcella-Baratheon': 0.03763440860215054,
#  'Petyr-Baelish': 0.13978494623655915,
#  'Rickon-Stark': 0.048387096774193554,
#  'Robb-Stark': 0.18817204301075272,
#  'Rodrik-Cassel': 0.09677419354838711,
#  'Sandor-Clegane': 0.08602150537634409,
#  'Sansa-Stark': 0.18817204301075272,
#  'Syrio-Forel': 0.016129032258064516,
#  'Tommen-Baratheon': 0.043010752688172046,
#  'Vayon-Poole': 0.02688172043010753,
#  'Yoren': 0.03763440860215054,
#  'Arys-Oakheart': 0.005376344086021506,
#  'Balon-Greyjoy': 0.010752688172043012,
#  'Balon-Swann': 0.010752688172043012,
#  'Renly-Baratheon': 0.09677419354838711,
#  'Barristan-Selmy': 0.07526881720430108,
#  'Boros-Blount': 0.02688172043010753,
#  'Pycelle': 0.07526881720430108,
#  'Varys': 0.0913978494623656,
#  'Jaremy-Rykker': 0.021505376344086023,
#  'Luwin': 0.09677419354838711,
#  'Mance-Rayder': 0.005376344086021506,
#  'Theon-Greyjoy': 0.08064516129032259,
#  'Waymar-Royce': 0.016129032258064516,
#  'Beric-Dondarrion': 0.03225806451612903,
#  'Gregor-Clegane': 0.06451612903225806,
#  'Loras-Tyrell': 0.07526881720430108,
#  'Thoros-of-Myr': 0.005376344086021506,
#  'Hali': 0.005376344086021506,
#  'Hallis-Mollen': 0.02688172043010753,
#  'Hodor': 0.021505376344086023,
#  'Hullen': 0.03225806451612903,
#  'Joseth': 0.010752688172043012,
#  'Nan': 0.021505376344086023,
#  'Osha': 0.016129032258064516,
#  'Rickard-Karstark': 0.05376344086021506,
#  'Rickard-Stark': 0.010752688172043012,
#  'Stiv': 0.010752688172043012,
#  'Lyanna-Stark': 0.021505376344086023,
#  'Bronn': 0.05376344086021506,
#  'Chiggen': 0.016129032258064516,
#  'Marillion': 0.02688172043010753,
#  'Shae': 0.010752688172043012,
#  'Shagga': 0.03225806451612903,
#  'Vardis-Egen': 0.03225806451612903,
#  'Willis-Wode': 0.03225806451612903,
#  'Brynden-Tully': 0.05913978494623656,
#  'Edmure-Tully': 0.05913978494623656,
#  'Hoster-Tully': 0.02688172043010753,
#  'Lysa-Arryn': 0.08064516129032259,
#  'Nestor-Royce': 0.010752688172043012,
#  'Walder-Frey': 0.03763440860215054,
#  'Colemon': 0.010752688172043012,
#  'Donnel-Waynwood': 0.005376344086021506,
#  'Eon-Hunter': 0.016129032258064516,
#  'Jon-Umber-(Greatjon)': 0.043010752688172046,
#  'Masha-Heddle': 0.005376344086021506,
#  'Moreo-Tumitis': 0.005376344086021506,
#  'Mya-Stone': 0.005376344086021506,
#  'Mychel-Redfort': 0.005376344086021506,
#  'Robert-Arryn': 0.016129032258064516,
#  'Stevron-Frey': 0.010752688172043012,
#  'Tytos-Blackwood': 0.016129032258064516,
#  'Wendel-Manderly': 0.010752688172043012,
#  'Cayn': 0.016129032258064516,
#  'Janos-Slynt': 0.03763440860215054,
#  'Stannis-Baratheon': 0.06451612903225806,
#  'Chella': 0.005376344086021506,
#  'Clement-Piper': 0.005376344086021506,
#  'Karyl-Vance': 0.016129032258064516,
#  'Cohollo': 0.021505376344086023,
#  'Haggo': 0.03225806451612903,
#  'Qotho': 0.03763440860215054,
#  'Conn': 0.016129032258064516,
#  'Coratt': 0.005376344086021506,
#  'Doreah': 0.03225806451612903,
#  'Eroeh': 0.005376344086021506,
#  'Illyrio-Mopatis': 0.03225806451612903,
#  'Irri': 0.043010752688172046,
#  'Jhiqui': 0.02688172043010753,
#  'Mirri-Maz-Duur': 0.03225806451612903,
#  'Rhaegar-Targaryen': 0.03763440860215054,
#  'Viserys-Targaryen': 0.043010752688172046,
#  'Danwell-Frey': 0.016129032258064516,
#  'Hosteen-Frey': 0.010752688172043012,
#  'Jared-Frey': 0.010752688172043012,
#  'Dareon': 0.005376344086021506,
#  'Daryn-Hornwood': 0.010752688172043012,
#  'Torrhen-Karstark': 0.016129032258064516,
#  'Dolf': 0.005376344086021506,
#  'Donal-Noye': 0.005376344086021506,
#  'Jommo': 0.010752688172043012,
#  'Ogo': 0.016129032258064516,
#  'Rhaego': 0.005376344086021506,
#  'Dywen': 0.005376344086021506,
#  'Galbart-Glover': 0.03225806451612903,
#  'Gendry': 0.005376344086021506,
#  'High-Septon-(fat_one)': 0.010752688172043012,
#  'Howland-Reed': 0.005376344086021506,
#  'Jacks': 0.005376344086021506,
#  'Joss': 0.005376344086021506,
#  'Marq-Piper': 0.02688172043010753,
#  'Porther': 0.005376344086021506,
#  'Raymun-Darry': 0.010752688172043012,
#  'Tobho-Mott': 0.005376344086021506,
#  'Tregar': 0.005376344086021506,
#  'Varly': 0.005376344086021506,
#  'Wyl-(guard)': 0.021505376344086023,
#  'Wylla': 0.005376344086021506,
#  'Fogo': 0.005376344086021506,
#  'Roose-Bolton': 0.02688172043010753,
#  'Gared': 0.016129032258064516,
#  'Will-(prologue)': 0.010752688172043012,
#  'Oswell-Whent': 0.005376344086021506,
#  'Todder': 0.021505376344086023,
#  'Gunthor-son-of-Gurn': 0.005376344086021506,
#  'Harys-Swyft': 0.005376344086021506,
#  'Heward': 0.010752688172043012,
#  'Hobb': 0.005376344086021506,
#  'Hugh': 0.005376344086021506,
#  'Jafer-Flowers': 0.005376344086021506,
#  'Kevan-Lannister': 0.016129032258064516,
#  'Matthar': 0.005376344086021506,
#  'Othor': 0.005376344086021506,
#  'Maege-Mormont': 0.010752688172043012,
#  'Jonos-Bracken': 0.005376344086021506,
#  'Jyck': 0.010752688172043012,
#  'Morrec': 0.010752688172043012,
#  'Kurleket': 0.005376344086021506,
#  'Lancel-Lannister': 0.005376344086021506,
#  'Leo-Lefford': 0.005376344086021506,
#  'Mace-Tyrell': 0.010752688172043012,
#  'Lyn-Corbray': 0.005376344086021506,
#  'Paxter-Redwyne': 0.005376344086021506,
#  'Maegor-I-Targaryen': 0.005376344086021506,
#  'Mord': 0.005376344086021506,
#  'Randyll-Tarly': 0.005376344086021506,
#  'Timett': 0.010752688172043012,
#  'Ulf-son-of-Umar': 0.005376344086021506}

# %%
# betweenness centrality (weighted and unweighted)
nx.betweenness_centrality(g1)
# Out:
# {'Addam-Marbrand': 0.0,
#  'Jaime-Lannister': 0.0320095542681723,
#  'Tywin-Lannister': 0.026190475931508066,
#  'Aegon-I-Targaryen': 0.0,
#  'Daenerys-Targaryen': 0.08627015537511595,
#  'Eddard-Stark': 0.2696038913836117,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.010844715683425361,
#  'Alliser-Thorne': 0.005026701469957172,
#  'Bowen-Marsh': 0.0,
#  'Chett': 0.0,
#  'Clydas': 0.0,
#  'Jeor-Mormont': 0.028345621007255038,
#  'Jon-Snow': 0.17158135899829566,
#  'Samwell-Tarly': 0.014449634885820021,
#  'Aerys-II-Targaryen': 0.00048173749786653005,
#  'Brandon-Stark': 0.002080261918971597,
#  'Gerold-Hightower': 0.02144725370531822,
#  'Jon-Arryn': 0.012525043642810938,
#  'Robert-Baratheon': 0.21403028397371796,
#  'Aggo': 7.265329845975008e-05,
#  'Drogo': 0.06481224290874964,
#  'Jhogo': 4.359197907585004e-05,
#  'Jorah-Mormont': 0.012611106728154204,
#  'Quaro': 2.906131938390003e-05,
#  'Rakharo': 3.390487261455003e-05,
#  'Albett': 0.0,
#  'Halder': 0.0002102102102102102,
#  'Rast': 7.749685169040008e-05,
#  'Grenn': 0.0002024605250411702,
#  'Pypar': 7.459071975201007e-05,
#  'Tyrion-Lannister': 0.1902124972697492,
#  'Alyn': 0.0003145710264731398,
#  'Harwin': 0.0003166711322941555,
#  'Jory-Cassel': 0.01752453849363612,
#  'Tomard': 0.0002966978204169855,
#  'Arthur-Dayne': 0.0,
#  'Arya-Stark': 0.017495289470929955,
#  'Benjen-Stark': 0.03293306050027417,
#  'Bran-Stark': 0.05579958811784442,
#  'Catelyn-Stark': 0.1513952715347627,
#  'Cersei-Lannister': 0.026434677939526103,
#  'Desmond': 0.0,
#  'Ilyn-Payne': 0.0003199575146182485,
#  'Jeyne-Poole': 6.109796432377078e-05,
#  'Joffrey-Baratheon': 0.018949350296839806,
#  'Meryn-Trant': 0.0006984119660127081,
#  'Mordane': 0.0010561655570225142,
#  'Mycah': 0.0,
#  'Myrcella-Baratheon': 2.8230995972931453e-05,
#  'Petyr-Baelish': 0.009436743202985242,
#  'Rickon-Stark': 8.984632696126533e-05,
#  'Robb-Stark': 0.07298399629664767,
#  'Rodrik-Cassel': 0.00963397409313393,
#  'Sandor-Clegane': 0.006237666841098885,
#  'Sansa-Stark': 0.03714483664326785,
#  'Syrio-Forel': 0.00012300558547174553,
#  'Tommen-Baratheon': 0.000554548184780281,
#  'Vayon-Poole': 0.0,
#  'Yoren': 0.00021138387522088702,
#  'Arys-Oakheart': 0.0,
#  'Balon-Greyjoy': 0.0,
#  'Balon-Swann': 0.0,
#  'Renly-Baratheon': 0.009635188708026638,
#  'Barristan-Selmy': 0.0012358894598099792,
#  'Boros-Blount': 0.0,
#  'Pycelle': 0.0003210706351837933,
#  'Varys': 0.010794552272183802,
#  'Jaremy-Rykker': 0.01075268817204301,
#  'Luwin': 0.013182650228125651,
#  'Mance-Rayder': 0.0,
#  'Theon-Greyjoy': 0.00980833131274694,
#  'Waymar-Royce': 0.006708358729333187,
#  'Beric-Dondarrion': 0.01075268817204301,
#  'Gregor-Clegane': 0.002923862955280991,
#  'Loras-Tyrell': 0.022409577164998796,
#  'Thoros-of-Myr': 0.0,
#  'Hali': 0.0,
#  'Hallis-Mollen': 0.0,
#  'Hodor': 0.0,
#  'Hullen': 0.0004513970364915859,
#  'Joseth': 0.0,
#  'Nan': 0.0,
#  'Osha': 0.0,
#  'Rickard-Karstark': 0.009473682089536549,
#  'Rickard-Stark': 8.86701693153306e-05,
#  'Stiv': 0.0,
#  'Lyanna-Stark': 3.321293643874289e-05,
#  'Bronn': 0.004124576359910305,
#  'Chiggen': 0.0,
#  'Marillion': 0.0,
#  'Shae': 0.0,
#  'Shagga': 0.02159256030223772,
#  'Vardis-Egen': 0.0011877067734453138,
#  'Willis-Wode': 0.00038763506505441997,
#  'Brynden-Tully': 0.00383234320543726,
#  'Edmure-Tully': 0.01963307983379491,
#  'Hoster-Tully': 0.0003909562718491462,
#  'Lysa-Arryn': 0.01821323157123013,
#  'Nestor-Royce': 0.0,
#  'Walder-Frey': 0.032338618467650716,
#  'Colemon': 0.0,
#  'Donnel-Waynwood': 0.0,
#  'Eon-Hunter': 0.0,
#  'Jon-Umber-(Greatjon)': 0.0033242714657788115,
#  'Masha-Heddle': 0.0,
#  'Moreo-Tumitis': 0.0,
#  'Mya-Stone': 0.0,
#  'Mychel-Redfort': 0.0,
#  'Robert-Arryn': 0.0,
#  'Stevron-Frey': 0.0,
#  'Tytos-Blackwood': 0.01075268817204301,
#  'Wendel-Manderly': 0.0,
#  'Cayn': 2.179598953792502e-05,
#  'Janos-Slynt': 0.0,
#  'Stannis-Baratheon': 0.0004430380168891369,
#  'Chella': 0.0,
#  'Clement-Piper': 0.0,
#  'Karyl-Vance': 0.01075268817204301,
#  'Cohollo': 0.0,
#  'Haggo': 6.780974522910006e-05,
#  'Qotho': 0.00011624527753560009,
#  'Conn': 0.01075268817204301,
#  'Coratt': 0.0,
#  'Doreah': 1.1624527753560013e-05,
#  'Eroeh': 0.0,
#  'Illyrio-Mopatis': 0.0011992863048539452,
#  'Irri': 9.590235396687009e-05,
#  'Jhiqui': 0.0,
#  'Mirri-Maz-Duur': 4.8435532306500046e-05,
#  'Rhaegar-Targaryen': 0.0028204821920682827,
#  'Viserys-Targaryen': 0.002857503691485831,
#  'Danwell-Frey': 0.02138913106655042,
#  'Hosteen-Frey': 0.0,
#  'Jared-Frey': 0.0,
#  'Dareon': 0.0,
#  'Daryn-Hornwood': 0.0,
#  'Torrhen-Karstark': 0.00027229994971930455,
#  'Dolf': 0.0,
#  'Donal-Noye': 0.0,
#  'Jommo': 0.0,
#  'Ogo': 0.01075268817204301,
#  'Rhaego': 0.0,
#  'Dywen': 0.0,
#  'Galbart-Glover': 0.0008706693487442282,
#  'Gendry': 0.0,
#  'High-Septon-(fat_one)': 0.0,
#  'Howland-Reed': 0.0,
#  'Jacks': 0.0,
#  'Joss': 0.0,
#  'Marq-Piper': 0.0062369436762998,
#  'Porther': 0.0,
#  'Raymun-Darry': 0.0,
#  'Tobho-Mott': 0.0,
#  'Tregar': 0.0,
#  'Varly': 0.0,
#  'Wyl-(guard)': 0.0016301901690895994,
#  'Wylla': 0.0,
#  'Fogo': 0.0,
#  'Roose-Bolton': 2.4944299137847526e-05,
#  'Gared': 0.004328212613689769,
#  'Will-(prologue)': 0.0,
#  'Oswell-Whent': 0.0,
#  'Todder': 0.0,
#  'Gunthor-son-of-Gurn': 0.0,
#  'Harys-Swyft': 0.0,
#  'Heward': 0.0,
#  'Hobb': 0.0,
#  'Hugh': 0.0,
#  'Jafer-Flowers': 0.0,
#  'Kevan-Lannister': 0.0,
#  'Matthar': 0.0,
#  'Othor': 0.0,
#  'Maege-Mormont': 0.0,
#  'Jonos-Bracken': 0.0,
#  'Jyck': 0.0,
#  'Morrec': 0.0,
#  'Kurleket': 0.0,
#  'Lancel-Lannister': 0.0,
#  'Leo-Lefford': 0.0,
#  'Mace-Tyrell': 0.01075268817204301,
#  'Lyn-Corbray': 0.0,
#  'Paxter-Redwyne': 0.0,
#  'Maegor-I-Targaryen': 0.0,
#  'Mord': 0.0,
#  'Randyll-Tarly': 0.0,
#  'Timett': 0.0,
#  'Ulf-son-of-Umar': 0.0}

# %% [markdown]
# # Common Applications of Networks
#
# 1. Community Detection (Clustering)
# 2. Recommendation Engines

# %% [markdown]
# ## Community Detection
# ### Cliques
# <img src ="./resources/clique_mean_girls.jpg">
#
#
# ## Not this ^^^
#
# ---
#
# #### Clique: a subset of vertices in an undirected graph, such that every pair of vertices are adjacent to one another
# * Maximal Clique: a clique that, if an additional vertex was added, would no longer be a clique
# * Maximum Clique: the largest clique (and by definition a maximal clique)

# %% [markdown]
# How many maximal cliques are there in the diagram below? What is the maximum clique?

# %% [markdown]
# <img src = "./resources/too_many_cliques.png">
#
# How could we create a simple recommendation system from a clique?

# %% [markdown]
# ### Clustering Techniques
#
# If we want to find nodes that are clustered together, take a look at common techniques
#
# #### k-clique community clustering algorithm

# %% [markdown]
# <img src = "./resources/k_clique_clustering.png">

# %% [markdown]
# How many clusters are in this picture here?

# %% [markdown]
# ###  Girvan-Newman clustering algorithm
#    1. The betweenness of all existing edges in the network is calculated first.
#    2. The edge with the highest betweenness is removed.
#    3. The betweenness of all edges affected by the removal is recalculated.
#    4. Steps 2 and 3 are repeated until no edges remain.
#
#
# #### What does this remind you of?

# %% [markdown]
# <img src ="./resources/gn.jpg">
#
# #### Let's see which works better with the GOT network:

# %%
### Code Examples from GOT
from networkx.algorithms.community import k_clique_communities
k_clique = k_clique_communities(g1,3)
dict(enumerate(k_clique))
# Out:
# {0: frozenset({'Addam-Marbrand',
#             'Aegon-I-Targaryen',
#             'Aemon-Targaryen-(Maester-Aemon)',
#             'Aerys-II-Targaryen',
#             'Aggo',
#             'Albett',
#             'Alliser-Thorne',
#             'Alyn',
#             'Arya-Stark',
#             'Balon-Greyjoy',
#             'Balon-Swann',
#             'Barristan-Selmy',
#             'Benjen-Stark',
#             'Beric-Dondarrion',
#             'Boros-Blount',
#             'Bowen-Marsh',
#             'Bran-Stark',
#             'Brandon-Stark',
#             'Bronn',
#             'Brynden-Tully',
#             'Catelyn-Stark',
#             'Cayn',
#             'Cersei-Lannister',
#             'Chett',
#             'Chiggen',
#             'Cohollo',
#             'Colemon',
#             'Conn',
#             'Daenerys-Targaryen',
#             'Daryn-Hornwood',
#             'Desmond',
#             'Doreah',
#             'Drogo',
#             'Eddard-Stark',
#             'Edmure-Tully',
#             'Eon-Hunter',
#             'Galbart-Glover',
#             'Gerold-Hightower',
#             'Gregor-Clegane',
#             'Grenn',
#             'Haggo',
#             'Halder',
#             'Hallis-Mollen',
#             'Harwin',
#             'Heward',
#             'High-Septon-(fat_one)',
#             'Hodor',
#             'Hoster-Tully',
#             'Hullen',
#             'Illyrio-Mopatis',
#             'Ilyn-Payne',
#             'Irri',
#             'Jaime-Lannister',
#             'Janos-Slynt',
#             'Jaremy-Rykker',
#             'Jeor-Mormont',
#             'Jeyne-Poole',
#             'Jhiqui',
#             'Jhogo',
#             'Joffrey-Baratheon',
#             'Jon-Arryn',
#             'Jon-Snow',
#             'Jon-Umber-(Greatjon)',
#             'Jorah-Mormont',
#             'Jory-Cassel',
#             'Joseth',
#             'Karyl-Vance',
#             'Kevan-Lannister',
#             'Loras-Tyrell',
#             'Luwin',
#             'Lyanna-Stark',
#             'Lysa-Arryn',
#             'Maege-Mormont',
#             'Marillion',
#             'Marq-Piper',
#             'Meryn-Trant',
#             'Mirri-Maz-Duur',
#             'Mordane',
#             'Mycah',
#             'Myrcella-Baratheon',
#             'Nan',
#             'Nestor-Royce',
#             'Osha',
#             'Petyr-Baelish',
#             'Pycelle',
#             'Pypar',
#             'Qotho',
#             'Quaro',
#             'Rakharo',
#             'Rast',
#             'Raymun-Darry',
#             'Renly-Baratheon',
#             'Rhaegar-Targaryen',
#             'Rickard-Karstark',
#             'Rickon-Stark',
#             'Robb-Stark',
#             'Robert-Arryn',
#             'Robert-Baratheon',
#             'Rodrik-Cassel',
#             'Roose-Bolton',
#             'Samwell-Tarly',
#             'Sandor-Clegane',
#             'Sansa-Stark',
#             'Shae',
#             'Shagga',
#             'Stannis-Baratheon',
#             'Stevron-Frey',
#             'Stiv',
#             'Syrio-Forel',
#             'Theon-Greyjoy',
#             'Timett',
#             'Todder',
#             'Tomard',
#             'Tommen-Baratheon',
#             'Torrhen-Karstark',
#             'Tyrion-Lannister',
#             'Tytos-Blackwood',
#             'Tywin-Lannister',
#             'Vardis-Egen',
#             'Varys',
#             'Vayon-Poole',
#             'Viserys-Targaryen',
#             'Walder-Frey',
#             'Wendel-Manderly',
#             'Willis-Wode',
#             'Wyl-(guard)',
#             'Yoren'}),
#  1: frozenset({'Gared', 'Waymar-Royce', 'Will-(prologue)'}),
#  2: frozenset({'Danwell-Frey', 'Hosteen-Frey', 'Jared-Frey'}),
#  3: frozenset({'Drogo', 'Jommo', 'Ogo'}),
#  4: frozenset({'Jyck', 'Morrec', 'Tyrion-Lannister'})}

# %%
from networkx.algorithms.community import girvan_newman
community = girvan_newman(g1)
comm_iter1 = tuple(sorted(c) for c in next(community))
dict(enumerate(comm_iter1))
# Out:
# {0: ['Addam-Marbrand',
#   'Aemon-Targaryen-(Maester-Aemon)',
#   'Aerys-II-Targaryen',
#   'Albett',
#   'Alliser-Thorne',
#   'Alyn',
#   'Arthur-Dayne',
#   'Arya-Stark',
#   'Arys-Oakheart',
#   'Balon-Greyjoy',
#   'Balon-Swann',
#   'Barristan-Selmy',
#   'Benjen-Stark',
#   'Beric-Dondarrion',
#   'Boros-Blount',
#   'Bowen-Marsh',
#   'Bran-Stark',
#   'Brandon-Stark',
#   'Bronn',
#   'Brynden-Tully',
#   'Catelyn-Stark',
#   'Cayn',
#   'Cersei-Lannister',
#   'Chella',
#   'Chett',
#   'Chiggen',
#   'Clement-Piper',
#   'Clydas',
#   'Colemon',
#   'Conn',
#   'Coratt',
#   'Danwell-Frey',
#   'Dareon',
#   'Daryn-Hornwood',
#   'Desmond',
#   'Dolf',
#   'Donal-Noye',
#   'Donnel-Waynwood',
#   'Dywen',
#   'Eddard-Stark',
#   'Edmure-Tully',
#   'Eon-Hunter',
#   'Galbart-Glover',
#   'Gared',
#   'Gendry',
#   'Gerold-Hightower',
#   'Gregor-Clegane',
#   'Grenn',
#   'Gunthor-son-of-Gurn',
#   'Halder',
#   'Hali',
#   'Hallis-Mollen',
#   'Harwin',
#   'Harys-Swyft',
#   'Heward',
#   'High-Septon-(fat_one)',
#   'Hobb',
#   'Hodor',
#   'Hosteen-Frey',
#   'Hoster-Tully',
#   'Howland-Reed',
#   'Hugh',
#   'Hullen',
#   'Ilyn-Payne',
#   'Jacks',
#   'Jafer-Flowers',
#   'Jaime-Lannister',
#   'Janos-Slynt',
#   'Jared-Frey',
#   'Jaremy-Rykker',
#   'Jeor-Mormont',
#   'Jeyne-Poole',
#   'Joffrey-Baratheon',
#   'Jon-Arryn',
#   'Jon-Snow',
#   'Jon-Umber-(Greatjon)',
#   'Jonos-Bracken',
#   'Jory-Cassel',
#   'Joseth',
#   'Joss',
#   'Jyck',
#   'Karyl-Vance',
#   'Kevan-Lannister',
#   'Kurleket',
#   'Lancel-Lannister',
#   'Leo-Lefford',
#   'Loras-Tyrell',
#   'Luwin',
#   'Lyanna-Stark',
#   'Lyn-Corbray',
#   'Lysa-Arryn',
#   'Mace-Tyrell',
#   'Maege-Mormont',
#   'Maegor-I-Targaryen',
#   'Mance-Rayder',
#   'Marillion',
#   'Marq-Piper',
#   'Masha-Heddle',
#   'Matthar',
#   'Meryn-Trant',
#   'Mord',
#   'Mordane',
#   'Moreo-Tumitis',
#   'Morrec',
#   'Mya-Stone',
#   'Mycah',
#   'Mychel-Redfort',
#   'Myrcella-Baratheon',
#   'Nan',
#   'Nestor-Royce',
#   'Osha',
#   'Oswell-Whent',
#   'Othor',
#   'Paxter-Redwyne',
#   'Petyr-Baelish',
#   'Porther',
#   'Pycelle',
#   'Pypar',
#   'Randyll-Tarly',
#   'Rast',
#   'Raymun-Darry',
#   'Renly-Baratheon',
#   'Rhaegar-Targaryen',
#   'Rickard-Karstark',
#   'Rickard-Stark',
#   'Rickon-Stark',
#   'Robb-Stark',
#   'Robert-Arryn',
#   'Robert-Baratheon',
#   'Rodrik-Cassel',
#   'Roose-Bolton',
#   'Samwell-Tarly',
#   'Sandor-Clegane',
#   'Sansa-Stark',
#   'Shae',
#   'Shagga',
#   'Stannis-Baratheon',
#   'Stevron-Frey',
#   'Stiv',
#   'Syrio-Forel',
#   'Theon-Greyjoy',
#   'Thoros-of-Myr',
#   'Timett',
#   'Tobho-Mott',
#   'Todder',
#   'Tomard',
#   'Tommen-Baratheon',
#   'Torrhen-Karstark',
#   'Tregar',
#   'Tyrion-Lannister',
#   'Tytos-Blackwood',
#   'Tywin-Lannister',
#   'Ulf-son-of-Umar',
#   'Vardis-Egen',
#   'Varly',
#   'Varys',
#   'Vayon-Poole',
#   'Walder-Frey',
#   'Waymar-Royce',
#   'Wendel-Manderly',
#   'Will-(prologue)',
#   'Willis-Wode',
#   'Wyl-(guard)',
#   'Wylla',
#   'Yoren'],
#  1: ['Aegon-I-Targaryen',
#   'Aggo',
#   'Cohollo',
#   'Daenerys-Targaryen',
#   'Doreah',
#   'Drogo',
#   'Eroeh',
#   'Fogo',
#   'Haggo',
#   'Illyrio-Mopatis',
#   'Irri',
#   'Jhiqui',
#   'Jhogo',
#   'Jommo',
#   'Jorah-Mormont',
#   'Mirri-Maz-Duur',
#   'Ogo',
#   'Qotho',
#   'Quaro',
#   'Rakharo',
#   'Rhaego',
#   'Viserys-Targaryen']}

# %% [markdown]
# Evaluating network clustering algorithms (https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0159161&type=printable)

# %% [markdown]
# ## Recommendations
#
# ####  Ego Network: A subset of a graph composed of a central node (ego) and all of the nodes the ego is connected to (alters)
#
# A simple recommendation system is: given an ego node, recommend items that are contained with its ego network
#
# <img src = "./resources/egonet3.jpg">
# This could yield a lot of results! How might we create more precise recommendations?
#
# http://www.steveborgatti.com/papers/egobet.pdf

# %%
# !gzip -d resources/books_meta.txt.gz

# %%
fhr = open('resources/books_meta.txt', 'r',
           encoding='utf-8', errors='ignore')
books_meta_dict = {}
fhr.readline()

# Parse data from each ASIN entry
for record in fhr:

    # Split the record attributes on TAB
    attr = record.split('\t')

    # Create a meta dictionary
    meta = {}

    # Read the attributes into key = ASIN , value= meta - where meta is a dictionary of attributes (except ASIN)
    meta['Id'] = attr[0].strip()
    ASIN = attr[1].strip()
    meta['Title'] = attr[2].strip()
    meta['Categories'] = attr[3].strip()
    meta['Group'] = attr[4].strip()

    # Convert numeric data to integers and floats accordingly
    meta['SalesRank'] = int(attr[5].strip())
    meta['TotalReviews'] = int(attr[6].strip())
    meta['AvgRating'] = float(attr[7].strip())
    meta['DegreeCentrality'] = int(attr[8].strip())
    meta['ClusteringCoeff'] = float(attr[9].strip())

    # Write metadata as value with key ASIN
    books_meta_dict[ASIN] = meta

# Close the file reader
fhr.close()
len(books_meta_dict)
# Out:
# 393561

# %%
books_meta_dict
# Out:
# {'0827229534': {'Id': '1',
#   'Title': 'Patterns of Preaching: A Sermon Sampler',
#   'Categories': 'clergi sermon subject religion preach spiritu christian book',
#   'Group': 'Book',
#   'SalesRank': 396585,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 8,
#   'ClusteringCoeff': 0.8},
#  '0738700797': {'Id': '2',
#   'Title': 'Candlemas: Feast of Flames',
#   'Categories': 'subject witchcraft earth religion spiritu base book wicca',
#   'Group': 'Book',
#   'SalesRank': 168596,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 9,
#   'ClusteringCoeff': 0.85},
#  '0486287785': {'Id': '3',
#   'Title': 'World War II Allied Fighter Planes Trading Cards',
#   'Categories': 'general hobbi subject craft home garden book',
#   'Group': 'Book',
#   'SalesRank': 1270652,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0842328327': {'Id': '4',
#   'Title': 'Life Application Bible Commentary: 1 and 2 Timothy and Titus',
#   'Categories': 'spiritu translat commentari christian book guid general subject testament life text applic sacr studi discipleship religion new live bibl histori refer',
#   'Group': 'Book',
#   'SalesRank': 631289,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.79},
#  '1577943082': {'Id': '5',
#   'Title': 'Prayers That Avail Much for Business: Executive',
#   'Categories': 'subject religion spiritu busi christian live worship book prayerbook devot',
#   'Group': 'Book',
#   'SalesRank': 455160,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 1.0},
#  '0486220125': {'Id': '6',
#   'Title': 'How the Other Half Lives: Studies Among the Tenements of New York',
#   'Categories': 'art general nonfict jewish subject essay camera america unit state sociolog photo photographi social book urban scienc histori categori',
#   'Group': 'Book',
#   'SalesRank': 188784,
#   'TotalReviews': 17,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.8},
#  '0231118597': {'Id': '8',
#   'Title': 'Losing Matt Shepard',
#   'Categories': 'nonfict general subject polit criminolog crimin gay crime book lesbian u',
#   'Group': 'Book',
#   'SalesRank': 277409,
#   'TotalReviews': 15,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.59},
#  '1859677800': {'Id': '9',
#   'Title': 'Making Bread: The Taste of Traditional Home-Baking',
#   'Categories': 'wine subject food bake book cook bread',
#   'Group': 'Book',
#   'SalesRank': 949166,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375709363': {'Id': '10',
#   'Title': 'The Edward Said Reader',
#   'Categories': 'nonfict general subject literatur anthropolog cultur polit critic social book theori scienc histori fiction',
#   'Group': 'Book',
#   'SalesRank': 220379,
#   'TotalReviews': 6,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.93},
#  '0871318237': {'Id': '11',
#   'Title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life',
#   'Categories': 'mind general subject specialti health unknown altern bodi technic medic book profession holist store jp medicin',
#   'Group': 'Book',
#   'SalesRank': 412962,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.43},
#  '1590770218': {'Id': '12',
#   'Title': 'Fantastic Food with Splenda : 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories',
#   'Categories': 'diabet weight low book loss cook wine general subject health food carbohydr bodi condiment free sugar fat carb nutrit condit herb ingredi diet mind special spice',
#   'Group': 'Book',
#   'SalesRank': 24741,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '0313230269': {'Id': '13',
#   'Title': 'Clockwork Worlds : Mechanized Environments in SF (Contributions to the Study of Science Fiction and Fantasy)',
#   'Categories': 'general subject literatur critic fantasi book theori scienc histori fiction',
#   'Group': 'Book',
#   'SalesRank': 2895088,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1559362022': {'Id': '15',
#   'Title': 'Wake Up and Smell the Coffee',
#   'Categories': 'art general bogosian drama literatur b subject perform author unit eric z state theater photographi book fiction',
#   'Group': 'Book',
#   'SalesRank': 518927,
#   'TotalReviews': 8,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.95},
#  '0195110382': {'Id': '16',
#   'Title': 'War at Sea: A Naval History of World War II',
#   'Categories': 'general militari naval ii subject war world book histori',
#   'Group': 'Book',
#   'SalesRank': 631564,
#   'TotalReviews': 10,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '0849311012': {'Id': '17',
#   'Title': 'Telecommunications Cost Management',
#   'Categories': 'hardwar system busi leadership telecommun book com offic general subject internet econom store oper comput amazon engin microprocessor manufactur manag home design invest industri',
#   'Group': 'Book',
#   'SalesRank': 570183,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  '078510870X': {'Id': '19',
#   'Title': 'Ultimate Marvel Team-Up',
#   'Categories': 'subject literatur superhero marvel comic horror fantasi scienc graphic book publish novel teen mysteri children fiction',
#   'Group': 'Book',
#   'SalesRank': 612475,
#   'TotalReviews': 8,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '3895780812': {'Id': '20',
#   'Title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications',
#   'Categories': 'general subject specialti internet technic intern comput medic book profession radiolog medicin',
#   'Group': 'Book',
#   'SalesRank': 179448,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 8,
#   'ClusteringCoeff': 0.85},
#  '0393049388': {'Id': '23',
#   'Title': 'Strange Fire: A Novel',
#   'Categories': 'general subject literatur mysteri book thriller contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 1277867,
#   'TotalReviews': 3,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553525476': {'Id': '24',
#   'Title': 'The Casebook of Sherlock Holmes, Volume 2 (Casebook of Sherlock Holmes)',
#   'Categories': 'entertain tape book holm format doyl radio general subject detect z sir mysteri broadcast author show thriller conan british sherlock arthur',
#   'Group': 'Book',
#   'SalesRank': 1545277,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0939165252': {'Id': '25',
#   'Title': 'Jailed for Freedom: American Women Win the Vote',
#   'Categories': 'nonfict subject elect govern book studi women histori',
#   'Group': 'Book',
#   'SalesRank': 326756,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '1590930509': {'Id': '26',
#   'Title': 'Chicken Little',
#   'Categories': 'folk general subject literatur stori fairi tale myth book age pictur children',
#   'Group': 'Book',
#   'SalesRank': 242571,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.55},
#  '0231096704': {'Id': '27',
#   'Title': 'The Columbia Anthology of Gay Literature',
#   'Categories': 'nonfict general subject literatur special group gay classic social book scienc lesbian studi fiction',
#   'Group': 'Book',
#   'SalesRank': 1119683,
#   'TotalReviews': 2,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '1893732290': {'Id': '28',
#   'Title': "God Knows Marriage Isn't Always Easy: 12 Ways to Add Zest (God Knows)",
#   'Categories': 'subject religion spiritu christian live relationship book marriag faith',
#   'Group': 'Book',
#   'SalesRank': 745886,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0781718791': {'Id': '29',
#   'Title': 'Advanced Pediatric Clinical Assessment: Skills and Procedures',
#   'Categories': 'neonat general subject specialti assess nurs pediatr technic diagnosi medic book profession medicin',
#   'Group': 'Book',
#   'SalesRank': 677416,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 8,
#   'ClusteringCoeff': 0.78},
#  '0471150274': {'Id': '30',
#   'Title': 'Solving Statics Problems with MathCAD',
#   'Categories': 'general subject aerospac specialti jp unknown advanc civil book mechan engin store',
#   'Group': 'Book',
#   'SalesRank': 227883,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.9},
#  '0895872218': {'Id': '31',
#   'Title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining',
#   'Categories': 'lodg busi state book com cook offic wine general subject south food profess store tourism u dine unit intern amazon categori hospit home region travel invest industri',
#   'Group': 'Book',
#   'SalesRank': 507787,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0761116982': {'Id': '32',
#   'Title': 'Staff Meals from Chanterelle',
#   'Categories': 'wine general subject atlant cook food gastronomi middl intern profession book region histori u',
#   'Group': 'Book',
#   'SalesRank': 150657,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.43},
#  '0439240751': {'Id': '33',
#   'Title': 'Double Jeopardy (T*Witches, 6)',
#   'Categories': 'adventur issu subject literatur magic specialti unknown witch horror seri fantasi children twin book scienc teen mysteri store jp fiction',
#   'Group': 'Book',
#   'SalesRank': 97166,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.51},
#  '0618111212': {'Id': '35',
#   'Title': 'Burnt Toast on Davenport Street',
#   'Categories': 'general subject literatur magic horror fantasi anim dog humor book age scienc pictur mysteri children fiction',
#   'Group': 'Book',
#   'SalesRank': 317983,
#   'TotalReviews': 5,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '1898630038': {'Id': '36',
#   'Title': 'Uists & Barra (Pevensey Island guides)',
#   'Categories': 'general great britain subject scotland europ amazon com book travel store categori',
#   'Group': 'Book',
#   'SalesRank': 1406353,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0787950599': {'Id': '38',
#   'Title': 'Resolving Conflicts At Work : A Complete Guide for Everyone on the Job',
#   'Categories': 'secret personnel busi occup book com guid offic organiz general subject health life internet bodi profess store counsel success resourc primer comput amazon mind biographi digit cultur manag home human psycholog invest industri',
#   'Group': 'Book',
#   'SalesRank': 644042,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.87},
#  '0312199406': {'Id': '39',
#   'Title': 'Night of Many Dreams : A Novel',
#   'Categories': 'general subject literatur specialti popular club book contemporari store fiction',
#   'Group': 'Book',
#   'SalesRank': 57186,
#   'TotalReviews': 22,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.91},
#  '1573221740': {'Id': '40',
#   'Title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other',
#   'Categories': 'general biographi subject parent adult home famili remodel memoir garden relationship book design renov child',
#   'Group': 'Book',
#   'SalesRank': 678019,
#   'TotalReviews': 8,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0130132543': {'Id': '41',
#   'Title': 'Workbook: The Long-Term Care Nursing Assistant',
#   'Categories': 'hospic subject care nurs technic medic book profession patient physician refer medicin',
#   'Group': 'Book',
#   'SalesRank': 2014896,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486268780': {'Id': '43',
#   'Title': 'Selected Poems (Dover Thrift Editions)',
#   'Categories': 'general subject literatur w singl author unit walt z state world poetri th classic book centuri whitman fiction',
#   'Group': 'Book',
#   'SalesRank': 260300,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 9,
#   'ClusteringCoeff': 0.57},
#  '1861007418': {'Id': '45',
#   'Title': 'Beginning ASP.NET Databases using C#',
#   'Categories': 'databas general subject religion web page spiritu eschatolog c internet christian comput theolog activ book server languag tool program',
#   'Group': 'Book',
#   'SalesRank': 48408,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 9,
#   'ClusteringCoeff': 0.41},
#  '0826449379': {'Id': '46',
#   'Title': "Alternative Worlds in Fantasy Fiction (Contemporary Classics of Children's Literature)",
#   'Categories': 'general subject literatur parent read famili critic fantasi classic book theori scienc teen guid histori fiction',
#   'Group': 'Book',
#   'SalesRank': 1115213,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.0},
#  '0590568833': {'Id': '47',
#   'Title': 'How to Kill a Monster (Goosebumps)',
#   'Categories': 'literatur book r fiction general subject l z age mysteri author stine scienc children illustr horror fantasi chill obsess monster spine',
#   'Group': 'Book',
#   'SalesRank': 654748,
#   'TotalReviews': 10,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0439420717': {'Id': '48',
#   'Title': 'Scooby-doo Mysteries #24 (Scooby-Doo Mysteries)',
#   'Categories': 'espionag literatur j popular seri del book fiction subject detect z mysteri scoobi author humor scienc children doo cultur horror fantasi jame chill spine',
#   'Group': 'Book',
#   'SalesRank': 529184,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.81},
#  '0687054532': {'Id': '51',
#   'Title': 'Out on the Edge: A Wake-Up Call for Church Leaders on the Edge of the Media Reformation',
#   'Categories': 'clergi general subject religion spiritu church christian pentecost book ministri histori protestant',
#   'Group': 'Book',
#   'SalesRank': 505266,
#   'TotalReviews': 7,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.88},
#  '0875420532': {'Id': '52',
#   'Title': "Secrets of Gypsy Love Magick (Llewellyn's New Age Series)",
#   'Categories': 'mind general nonfict folklor religion subject love magic health spiritu bodi sociolog occult scienc social relationship book romanc mytholog',
#   'Group': 'Book',
#   'SalesRank': 409481,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '0944708498': {'Id': '53',
#   'Title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future',
#   'Categories': 'financi plan general financ retir person subject parent home famili invest busi amazon com book age store offic',
#   'Group': 'Book',
#   'SalesRank': 566643,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0613100093': {'Id': '54',
#   'Title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)',
#   'Categories': 'adventur general subject taci literatur place action friendship seri betsi classic social book age peopl children situat fiction',
#   'Group': 'Book',
#   'SalesRank': 629348,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.83},
#  '0486275035': {'Id': '55',
#   'Title': 'Goldilocks and the Three Bears : Full-Color Picture Book (Dover Little Activity Books)',
#   'Categories': 'general subject literatur humor book age children',
#   'Group': 'Book',
#   'SalesRank': 1269904,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1550416243': {'Id': '56',
#   'Title': 'Three Bricks Shy of a Load: A Collection of True Stories About Ordinary People Doing Really Dumb Stuff!',
#   'Categories': 'general entertain subject essay humor book',
#   'Group': 'Book',
#   'SalesRank': 2167012,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0398068917': {'Id': '57',
#   'Title': 'Investigating Computer Crime: A Primer for Security Managers',
#   'Categories': 'general hacker digit subject cultur manag home internet busi project comput amazon com book secur store offic',
#   'Group': 'Book',
#   'SalesRank': 1501773,
#   'TotalReviews': 1,
#   'AvgRating': 1.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087842461X': {'Id': '58',
#   'Title': 'Raptors of the Rockies: Biology of the Birds of Prey and Species Accounts of the Raptors of the Rockies',
#   'Categories': 'general subject specialti jp unit unknown outdoor rocki natur state bird book mountain region field birdwatch guid refer store',
#   'Group': 'Book',
#   'SalesRank': 1091842,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393971694': {'Id': '60',
#   'Title': 'Renaissance Music: Music in Western Europe, 1400-1600 (Norton Introduction to Music History)',
#   'Categories': 'art general entertain subject specialti use music critic appreci new human europ book textbook store histori',
#   'Group': 'Book',
#   'SalesRank': 373682,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 9,
#   'ClusteringCoeff': 0.76},
#  '1550373080': {'Id': '61',
#   'Title': 'Hermanos (Hablemos)',
#   'Categories': 'sibl infantil libro nonfict subject format famili place en spanish multilingu life bebe book español juvenil peopl año children',
#   'Group': 'Book',
#   'SalesRank': 890775,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0026879077': {'Id': '62',
#   'Title': 'Scoring High on the Stanford Achievement Test',
#   'Categories': 'school nonfict educ subject book children refer',
#   'Group': 'Book',
#   'SalesRank': 1157369,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.71},
#  '0966723821': {'Id': '63',
#   'Title': 'Historia De Cancer De Una Dietista : Informacion & Inspiracion para la Recuperacion & Curacion Sobreviviente de tres canceres',
#   'Categories': 'libro disord weight book academ format loss general subject oncolog health altern memoir bodi español diseas medicin nutrit cancer condit en memoria intern diet mind biographi special profession topic medic biografía',
#   'Group': 'Book',
#   'SalesRank': 613909,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.6},
#  '0689846088': {'Id': '64',
#   'Title': 'A Charlie Brown Christmas',
#   'Categories': 'general subject peopl place christma fiction pictur book age holiday children festiv',
#   'Group': 'Book',
#   'SalesRank': 423424,
#   'TotalReviews': 6,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.73},
#  '0273651870': {'Id': '65',
#   'Title': 'Economics for Business',
#   'Categories': 'general subject home invest busi amazon com book store offic',
#   'Group': 'Book',
#   'SalesRank': 963890,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0393037622': {'Id': '66',
#   'Title': 'Blood and Guts: A Short History of Medicine',
#   'Categories': 'general mathemat subject special book topic scienc histori medicin',
#   'Group': 'Book',
#   'SalesRank': 408761,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '1571515429': {'Id': '67',
#   'Title': 'Picture Me With My Friend Jesus: Girl Version (Picture Me)',
#   'Categories': 'biographi subject religion christian book age jesus children fiction',
#   'Group': 'Book',
#   'SalesRank': 784192,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0810114275': {'Id': '68',
#   'Title': 'Experiencing and the Creation of Meaning: A Philosophical and Psychological Approach to the Subjective (Studies in Phenomenology and Existential Philosophy)',
#   'Categories': 'epistemolog nonfict general subject philosophi book modern phenomenolog movement',
#   'Group': 'Book',
#   'SalesRank': 421103,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.74},
#  '0415925398': {'Id': '69',
#   'Title': 'Negotiated Empires: Centers and Peripheries in the New World, 1500-1820',
#   'Categories': 'historiographi general subject america histor book studi histori',
#   'Group': 'Book',
#   'SalesRank': 454490,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.8},
#  '0415223954': {'Id': '70',
#   'Title': 'Geographies of Young People: The Morally Contested Spaces of Identity (Critical Geographies)',
#   'Categories': 'nonfict general subject sociolog human social book scienc children studi geographi',
#   'Group': 'Book',
#   'SalesRank': 973410,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '157281196X': {'Id': '72',
#   'Title': 'Power of Flowers: An Archetypal Journey Through Nature',
#   'Categories': 'general entertain subject religion spiritu tarot new card book game age divin',
#   'Group': 'Book',
#   'SalesRank': 348412,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.93},
#  '0375803394': {'Id': '73',
#   'Title': 'The Perfect Plan (7th Heaven)',
#   'Categories': 'general subject literatur cultur religion famili place popular life seri christian heaven book age peopl seventh children',
#   'Group': 'Book',
#   'SalesRank': 561551,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.85},
#  '0113300174': {'Id': '74',
#   'Title': 'Service Delivery (It Infrastructure Library Series)',
#   'Categories': 'general biographi profil subject manag home invest primer busi scienc leadership amazon book com compani store refer offic',
#   'Group': 'Book',
#   'SalesRank': 27507,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '0786863919': {'Id': '75',
#   'Title': 'Disney A to Z : The Updated Official Encyclopedia (Disney a to Z)',
#   'Categories': 'art entertain subject americana cultur televis home pop garden antiqu book movi encyclopedia collect refer',
#   'Group': 'Book',
#   'SalesRank': 161879,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 8,
#   'ClusteringCoeff': 0.53},
#  '1581150040': {'Id': '76',
#   'Title': "The Writer's Legal Guide (2nd ed)",
#   'Categories': 'patent intellectu general copyright trademark subject properti technic authorship write profession book law publish guid refer practic',
#   'Group': 'Book',
#   'SalesRank': 1151885,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312982178': {'Id': '77',
#   'Title': 'Water Touching Stone',
#   'Categories': 'general subject book thriller mysteri',
#   'Group': 'Book',
#   'SalesRank': 27012,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0874850037': {'Id': '78',
#   'Title': 'The Ebony Cookbook: A Date With a Dish',
#   'Categories': 'wine general subject african food intern book region american cook u',
#   'Group': 'Book',
#   'SalesRank': 140480,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.69},
#  '0811726371': {'Id': '79',
#   'Title': "Today's Military Wife: Meeting the Challenges of Service Life (Today's Military Wife)",
#   'Categories': 'nonfict general subject book studi women refer',
#   'Group': 'Book',
#   'SalesRank': 7437,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 11,
#   'ClusteringCoeff': 0.69},
#  '1884997015': {'Id': '80',
#   'Title': 'In Quest of God: The Saga of an Extraordinary Pilgrimage',
#   'Categories': 'general subject biographi religion spiritu author z memoir eastern book eknath e easwaran',
#   'Group': 'Book',
#   'SalesRank': 533031,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0140430407': {'Id': '82',
#   'Title': 'Puddnhead Wilson : And, Those Extraordinary Twins (The Penguin English Library)',
#   'Categories': 'general subject literatur mark author unit z state world paperback th classic book centuri twain fiction',
#   'Group': 'Book',
#   'SalesRank': 60668,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.59},
#  '059516630X': {'Id': '83',
#   'Title': 'A Candle for Bobby',
#   'Categories': 'general subject literatur book contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 3272795,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0912500476': {'Id': '85',
#   'Title': 'Amamantar Sencillo y Puro',
#   'Categories': 'subject toddler specialti parent famili feed music categori book store video babi breastfeed',
#   'Group': 'Book',
#   'SalesRank': 1246085,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0807205249': {'Id': '86',
#   'Title': 'Junie B. Jones Collection: Books 9-12',
#   'Categories': 'general literatur tape book format children fiction',
#   'Group': 'Book',
#   'SalesRank': 1525696,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415157528': {'Id': '87',
#   'Title': 'Colloquial Polish: The Complete Course for Beginners (Colloquial Series (Book Only))',
#   'Categories': 'english general foreign subject instruct dictionari polish thesaurus book languag refer',
#   'Group': 'Book',
#   'SalesRank': 393166,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.81},
#  '039802278X': {'Id': '88',
#   'Title': 'Normal and Abnormal Development: The Influence of Primitive Reflexes on Motor Development',
#   'Categories': '',
#   'Group': 'Book',
#   'SalesRank': 353149,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0671727737': {'Id': '90',
#   'Title': 'The Eagle Has Landed',
#   'Categories': 'spi subject stori intrigu tale book thriller mysteri',
#   'Group': 'Book',
#   'SalesRank': 841921,
#   'TotalReviews': 46,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.9},
#  '1566913810': {'Id': '91',
#   'Title': 'Foghorn Outdoors: New England Hiking 3 Ed: The Complete Guide to More than 380 Hikes',
#   'Categories': 'subject unit northeast state new amazon com book england region travel store categori',
#   'Group': 'Book',
#   'SalesRank': 333198,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.7},
#  '037575380X': {'Id': '92',
#   'Title': 'Black No More : A Novel (Modern Library (Paperback))',
#   'Categories': 'general short subject literatur stori unit state world classic book contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 251469,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 10,
#   'ClusteringCoeff': 0.51},
#  '0965740056': {'Id': '93',
#   'Title': 'BizPricer¿ Business Valuation Manual w/Software',
#   'Categories': 'general financ subject small home invest busi entrepreneurship amazon corpor book com store offic',
#   'Group': 'Book',
#   'SalesRank': 1485593,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '039572774X': {'Id': '94',
#   'Title': 'The American Heritage Dictionary of Idioms',
#   'Categories': 'english general subject slang idiom dictionari book thesaurus refer',
#   'Group': 'Book',
#   'SalesRank': 166549,
#   'TotalReviews': 15,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 14,
#   'ClusteringCoeff': 0.52},
#  '0887402631': {'Id': '95',
#   'Title': 'The Heavy Flak Guns, 1933-1945: 88Mm, 105Mm, 128Mm, 150Mm, and Ballistic Directional Equipment',
#   'Categories': 'subject technolog book scienc histori',
#   'Group': 'Book',
#   'SalesRank': 1369585,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0310485002': {'Id': '96',
#   'Title': 'Becoming a Contagious Christian',
#   'Categories': 'discipleship general subject religion spiritu christian live book inspir protestant',
#   'Group': 'Book',
#   'SalesRank': 215846,
#   'TotalReviews': 21,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.69},
#  '042515517X': {'Id': '97',
#   'Title': 'Year of the Tiger',
#   'Categories': 'spi general subject literatur stori mysteri intrigu tale book thriller contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 509767,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.8},
#  '0071402306': {'Id': '99',
#   'Title': "An Employee's Guide to Stock Options",
#   'Categories': 'general financ subject person home option invest account busi technic amazon profession book com store offic',
#   'Group': 'Book',
#   'SalesRank': 228734,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.81},
#  '0787958743': {'Id': '100',
#   'Title': 'Guide to Effective Staff Development in Health Care Organizations : A Systems Approach to Successful Training (J-B AHA Press)',
#   'Categories': 'general subject administr polici technic medic book econom profession medicin',
#   'Group': 'Book',
#   'SalesRank': 783690,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '0743509315': {'Id': '101',
#   'Title': 'Separation Of Power',
#   'Categories': 'spi general subject literatur stori suspens intrigu polit tale cd thriller book format mysteri genr fiction',
#   'Group': 'Book',
#   'SalesRank': 612868,
#   'TotalReviews': 76,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 1.0},
#  '1858685486': {'Id': '102',
#   'Title': 'Mensa Visual Brainteasers',
#   'Categories': 'general entertain subject brain teaser logic book game puzzl',
#   'Group': 'Book',
#   'SalesRank': 576507,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '0151803870': {'Id': '103',
#   'Title': 'Selected Essays',
#   'Categories': 'general subject literatur religion essay spiritu author z eliot classic book e fiction',
#   'Group': 'Book',
#   'SalesRank': 324548,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0820451576': {'Id': '104',
#   'Title': 'Owning Culture: Authorship, Ownership, and Intellectual Property Law (Popular Culture and Everyday Life, Vol. 1)',
#   'Categories': 'general intellectu subject properti busi technic profession book law',
#   'Group': 'Book',
#   'SalesRank': 592661,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  '1555919332': {'Id': '105',
#   'Title': 'Learning in Overdrive: Designing Curriculum, Instruction, and Assessment from Standards : A Manual for Teachers',
#   'Categories': 'plan nonfict general financ subject educ standard assess pedagogi technic lesson profession book theori',
#   'Group': 'Book',
#   'SalesRank': 114176,
#   'TotalReviews': 2,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.3},
#  '0821825917': {'Id': '106',
#   'Title': 'Filtrations on the Homology of Algebraic Varieties (Memoirs of the American Mathematical Society, 529)',
#   'Categories': 'general subject mathemat book scienc',
#   'Group': 'Book',
#   'SalesRank': 1646865,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '038548125X': {'Id': '107',
#   'Title': 'Mothers and Daughters',
#   'Categories': 'art general nonfict subject essay camera parent famili sociolog photo photographi scienc social relationship book marriag motherhood categori',
#   'Group': 'Book',
#   'SalesRank': 432141,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.85},
#  '0838531377': {'Id': '108',
#   'Title': 'General Ophthalmology',
#   'Categories': 'otolaryngolog subject specialti ophthalmolog technic medic book profession surgeri medicin',
#   'Group': 'Book',
#   'SalesRank': 635566,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.61},
#  '0471346608': {'Id': '109',
#   'Title': 'Baby Basics : A Guide for New Parents',
#   'Categories': 'mind general subject pregnanc person toddler parent specialti health famili women music childbirth develop bodi infant book store video babi',
#   'Group': 'Book',
#   'SalesRank': 502928,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0684868008': {'Id': '110',
#   'Title': 'Casanova in Bohemia : A Novel',
#   'Categories': 'entertain amadeus biographi literatur subject music z memoir mozart wolfgang classic histor book peopl compos genr fiction',
#   'Group': 'Book',
#   'SalesRank': 92775,
#   'TotalReviews': 10,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 1.0},
#  '0736805656': {'Id': '111',
#   'Title': 'The Maine Coon Cat (Learning About Cats)',
#   'Categories': 'nonfict cat subject pet anim book children',
#   'Group': 'Book',
#   'SalesRank': 1612259,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1572315938': {'Id': '112',
#   'Title': 'Official Microsoft Image Composer Book',
#   'Categories': 'general subject web site illustr imag html internet develop comput commerc book design compos applic graphic',
#   'Group': 'Book',
#   'SalesRank': 682312,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0736625801': {'Id': '113',
#   'Title': 'Jesus: A Life',
#   'Categories': '',
#   'Group': 'Book',
#   'SalesRank': 2213377,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.43},
#  '0809240394': {'Id': '114',
#   'Title': 'Bowl Like a Pro',
#   'Categories': 'general subject book individu bowl sport',
#   'Group': 'Book',
#   'SalesRank': 887935,
#   'TotalReviews': 3,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0533139317': {'Id': '115',
#   'Title': 'Growing Millionaire Kids',
#   'Categories': 'general subject home invest busi amazon com book store offic',
#   'Group': 'Book',
#   'SalesRank': 1217413,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0820112518': {'Id': '116',
#   'Title': 'The Life of Benjamin West',
#   'Categories': 'art general biographi subject v z memoir photographi book west artist benjamin',
#   'Group': 'Book',
#   'SalesRank': 3312631,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0380819546': {'Id': '117',
#   'Title': 'Site Unseen : An Emma Fielding Mystery (Emma Fielding Mysteries)',
#   'Categories': 'general subject sleuth seri book thriller mysteri women',
#   'Group': 'Book',
#   'SalesRank': 38915,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '0590464272': {'Id': '118',
#   'Title': 'The Magic School Bus At The Waterworks : (autobus Magico Viaja Por...) (Magic School Bus)',
#   'Categories': 'libro literatur cole action seri book format fiction subject magic earli z age juvenil español work school adventur bruce author reader c en ficción natur scienc año children joanna infantil illustr pictur degen bus',
#   'Group': 'Book',
#   'SalesRank': 654728,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 1.0},
#  '0849943221': {'Id': '119',
#   'Title': 'Black Friday (Soul Survivor Series, Bk. 4)',
#   'Categories': 'spi general subject religion stori spiritu intrigu author tale l z paperback lahay tim book thriller mysteri fiction',
#   'Group': 'Book',
#   'SalesRank': 762209,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  '0140445684': {'Id': '120',
#   'Title': 'Capital : A Critique of Political Economy (Penguin Classics)',
#   'Categories': 'nonfict general subject polit communism philosophi radic social book thought ideolog',
#   'Group': 'Book',
#   'SalesRank': 17693,
#   'TotalReviews': 40,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 34,
#   'ClusteringCoeff': 0.59},
#  '0688060676': {'Id': '121',
#   'Title': 'Ten Black Dots',
#   'Categories': 'general subject specialti author c illustr music z children basic book age donald crew store concept babi',
#   'Group': 'Book',
#   'SalesRank': 144348,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.84},
#  '059047913X': {'Id': '123',
#   'Title': 'You Can Name 100 Dinosaurs!',
#   'Categories': 'nonfict general subject dinosaur anim book children babi',
#   'Group': 'Book',
#   'SalesRank': 651510,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '076453243X': {'Id': '125',
#   'Title': 'Adobe® InDesign¿ Bible',
#   'Categories': 'general subject web adob illustr html internet desktop develop comput book design indesign publish graphic',
#   'Group': 'Book',
#   'SalesRank': 405530,
#   'TotalReviews': 5,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0395530377': {'Id': '126',
#   'Title': 'Houghton Mifflin Mathematics: Practice Activity Level 7',
#   'Categories': 'general subject mathemat math natur technolog book scienc teen work children',
#   'Group': 'Book',
#   'SalesRank': 1804602,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0878301534': {'Id': '127',
#   'Title': 'Ballroom Dancing',
#   'Categories': 'art danc general subject perform popular photographi book ballroom refer',
#   'Group': 'Book',
#   'SalesRank': 36535,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.83},
#  '0312871880': {'Id': '128',
#   'Title': 'Irish Stew!',
#   'Categories': 'general subject literatur author sleuth women z seri g book greeley thriller mysteri literari andrew fiction',
#   'Group': 'Book',
#   'SalesRank': 368790,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 1.0},
#  '1579473024': {'Id': '129',
#   'Title': 'Cpt 2003: Current Procedural Terminology (Cpt / Current Procedural Terminology (Standard Edition))',
#   'Categories': 'record reimburs general subject manag administr polici technic refer medic book econom scienc profession histori practic medicin',
#   'Group': 'Book',
#   'SalesRank': 256979,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 12,
#   'ClusteringCoeff': 0.38},
#  '0767905288': {'Id': '130',
#   'Title': "The O'Reilly Factor: The Good, the Bad, and the Completely Ridiculous in American Life",
#   'Categories': 'nonfict general subject parti polit book practic u',
#   'Group': 'Book',
#   'SalesRank': 29460,
#   'TotalReviews': 375,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 14,
#   'ClusteringCoeff': 0.65},
#  '078795893X': {'Id': '131',
#   'Title': 'The 2R Manager: When to Relate, When to Require, and How to Do Both Effectively',
#   'Categories': 'general subject small manag home invest career busi entrepreneurship leadership amazon book com store offic',
#   'Group': 'Book',
#   'SalesRank': 122152,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '0743504097': {'Id': '132',
#   'Title': 'Iyanla Live! : Back to Basics (Iyanla Live!)',
#   'Categories': 'vanzant spiritu tape book self format growth general subject person health motiv z bodi religion author v philosophi inspir mind help transform psycholog iyanla',
#   'Group': 'Book',
#   'SalesRank': 868001,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 1.0},
#  '0877936528': {'Id': '134',
#   'Title': 'Growing Teen Disciples: Strategies for Really Effective Youth Ministry',
#   'Categories': 'clergi subject religion spiritu christian youth book ministri',
#   'Group': 'Book',
#   'SalesRank': 1646474,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0609608363': {'Id': '135',
#   'Title': 'Wondrous Contrivances : Technology at the Threshold',
#   'Categories': 'general subject mathemat america unit technolog state book scienc histori',
#   'Group': 'Book',
#   'SalesRank': 408802,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0452011604': {'Id': '136',
#   'Title': 'Understanding Islam: An Introduction to the Muslim World, Third Revised and Updated Edition',
#   'Categories': 'general subject religion spiritu book islam',
#   'Group': 'Book',
#   'SalesRank': 90195,
#   'TotalReviews': 14,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.0},
#  '0781433525': {'Id': '137',
#   'Title': 'Apples of Gold: A Six-Week Nurturing Program for Women',
#   'Categories': 'clergi general subject issu religion spiritu church christian live book organ inspir institut women',
#   'Group': 'Book',
#   'SalesRank': 129355,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0824518659': {'Id': '139',
#   'Title': 'The Sacred Impulse',
#   'Categories': 'general subject religion spiritu catholic outdoor natur environ christian book ecolog inspir',
#   'Group': 'Book',
#   'SalesRank': 846457,
#   'TotalReviews': 1,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786710772': {'Id': '140',
#   'Title': 'Power & Greed: A Short History of the World',
#   'Categories': 'general subject specialti unknown world book store histori jp',
#   'Group': 'Book',
#   'SalesRank': 788014,
#   'TotalReviews': 5,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1886110867': {'Id': '141',
#   'Title': 'Coach K: Building the Duke Dynasty : Building the Duke Dynasty',
#   'Categories': 'biographi general subject colleg basketbal book sport univers',
#   'Group': 'Book',
#   'SalesRank': 401565,
#   'TotalReviews': 10,
#   'AvgRating': 2.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0590108859': {'Id': '142',
#   'Title': 'Chemical Chaos (Horrible Science)',
#   'Categories': 'general subject natur chemistri book age scienc work children',
#   'Group': 'Book',
#   'SalesRank': 280529,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.93},
#  '080784991X': {'Id': '143',
#   'Title': 'Ghosts from the Coast',
#   'Categories': 'supernatur literatur spiritu state occult book unexplain fiction general folklor subject ghost social mysteri religion reader unit world scienc mytholog nonfict horror collect',
#   'Group': 'Book',
#   'SalesRank': 1079230,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0195044193': {'Id': '144',
#   'Title': 'The Paradox of Change: American Women in the 20th Century',
#   'Categories': 'general nonfict subject america unit state th book studi centuri women histori',
#   'Group': 'Book',
#   'SalesRank': 596032,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.58},
#  '1581127723': {'Id': '145',
#   'Title': 'The Bases of Chemical Thermodynamics: Volume 1',
#   'Categories': 'subject physic chemic theoret technic thermodynam chemistri dynam book profession scienc engin',
#   'Group': 'Book',
#   'SalesRank': 656347,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '0806626062': {'Id': '146',
#   'Title': 'More Prime Time Activities With Kids',
#   'Categories': 'general hobbi subject craft specialti home parent famili music garden activ book video store',
#   'Group': 'Book',
#   'SalesRank': 223675,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.83},
#  '0743202554': {'Id': '147',
#   'Title': 'The New Jewish Wedding, Revised',
#   'Categories': 'general subject religion home judaism spiritu life ritual garden wed book jewish refer practic',
#   'Group': 'Book',
#   'SalesRank': 11398,
#   'TotalReviews': 18,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 12,
#   'ClusteringCoeff': 0.36},
#  '0812550749': {'Id': '148',
#   'Title': 'Firebird',
#   'Categories': 'general subject merced author l z paperback fantasi book scienc lackey fiction',
#   'Group': 'Book',
#   'SalesRank': 77008,
#   'TotalReviews': 42,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 1.0},
#  '0764118218': {'Id': '150',
#   'Title': 'Vocabulary Builder: French : Mastering the Most Common French Words and Phrases (Vocabulary Builder Series)',
#   'Categories': 'foreign general french subject instruct dictionari word thesaurus book vocabulari languag refer',
#   'Group': 'Book',
#   'SalesRank': 966856,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0140272100': {'Id': '154',
#   'Title': 'Vanished',
#   'Categories': 'general subject literatur book contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 274214,
#   'TotalReviews': 22,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.83},
#  '0939343347': {'Id': '155',
#   'Title': 'Cowboy Mentality & the Big One That Got Away',
#   'Categories': 'general subject literatur singl author western unit state world poetri th book centuri genr fiction',
#   'Group': 'Book',
#   'SalesRank': 201196,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.7},
#  '0842374043': {'Id': '157',
#   'Title': 'What about Spiritual Warfare?',
#   'Categories': 'angelolog general subject religion spiritu angel christian warfar theolog book religi',
#   'Group': 'Book',
#   'SalesRank': 1058886,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553487388': {'Id': '159',
#   'Title': 'The Icicle Forest (Fairy School)',
#   'Categories': 'folk literatur place tale book fiction general subject magic social age mysteri situat fairi friendship antholog scienc children myth horror fantasi peopl',
#   'Group': 'Book',
#   'SalesRank': 606246,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 1.0},
#  '0804119368': {'Id': '160',
#   'Title': 'The Twisted Root (William Monk Novels (Paperback))',
#   'Categories': 'general subject british ann suspens author detect z paperback seri histor book perri thriller mysteri p',
#   'Group': 'Book',
#   'SalesRank': 271715,
#   'TotalReviews': 23,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 11,
#   'ClusteringCoeff': 0.66},
#  '0890541795': {'Id': '161',
#   'Title': 'Foliage Plant Diseases: Diagnosis & Control',
#   'Categories': 'biolog general subject entomolog home garden technic hous book plant scienc profession horticultur',
#   'Group': 'Book',
#   'SalesRank': 1166713,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0810939770': {'Id': '162',
#   'Title': 'Wildlife the Nature Paintings of Carl Brenders',
#   'Categories': 'art general subject z photographi book artist histori',
#   'Group': 'Book',
#   'SalesRank': 413356,
#   'TotalReviews': 6,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.69},
#  '0931892813': {'Id': '163',
#   'Title': 'Messages to Our Family',
#   'Categories': 'general subject religion spiritu new occult book age',
#   'Group': 'Book',
#   'SalesRank': 304224,
#   'TotalReviews': 2,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.83},
#  '0895296586': {'Id': '164',
#   'Title': "What's Really Wrong With You: A Revolutionary Look at How Muscles Affect Your Health",
#   'Categories': 'mind general subject disord health rheumatolog altern bodi technic massag diseas medic book intern profession therapi medicin',
#   'Group': 'Book',
#   'SalesRank': 224993,
#   'TotalReviews': 12,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '0807842109': {'Id': '165',
#   'Title': 'Passage of Darkness: The Ethnobiology of the Haitian Zombie',
#   'Categories': 'general nonfict subject religion spiritu sociolog social book ethnic scienc tribal practic',
#   'Group': 'Book',
#   'SalesRank': 286627,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 1.0},
#  '0226309045': {'Id': '166',
#   'Title': 'In the Arms of Africa: The Life of Colin Turnbull',
#   'Categories': 'adventur nonfict general specif biographi anthropolog psychologist explor subject group memoir scientist gay scienc profession book social academ lesbian',
#   'Group': 'Book',
#   'SalesRank': 488085,
#   'TotalReviews': 13,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  '0385332998': {'Id': '167',
#   'Title': 'Total Immersion',
#   'Categories': 'short general subject literatur stori unit state book fiction',
#   'Group': 'Book',
#   'SalesRank': 537058,
#   'TotalReviews': 4,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.69},
#  '1560799501': {'Id': '168',
# ...
#   'Title': "Is He Gay? : For Every Woman Who's Met the Ideal Man and is Wondering...Why Hasn't he Tried to Kiss Me?",
#   'Categories': 'mind general entertain subject strip relat love health comic sex bodi humor relationship book romanc marriag interperson novel graphic',
#   'Group': 'Book',
#   'SalesRank': 249924,
#   'TotalReviews': 18,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '0393701700': {'Id': '1344',
#   'Title': 'Words Were Originally Magic',
#   'Categories': 'mind mental counsel general subject nlp health psychotherapi behavior ta bodi book psycholog compuls',
#   'Group': 'Book',
#   'SalesRank': 105971,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.55},
#  '0761993924': {'Id': '1345',
#   'Title': 'Sex Ratio Patterns in the Indian Population : A Fresh Exploration',
#   'Categories': 'general nonfict subject specialti use gender new sociolog social book textbook scienc demographi store',
#   'Group': 'Book',
#   'SalesRank': 1971824,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375762698': {'Id': '1346',
#   'Title': 'Cracking the GRE Psychology Test, 6th Edition (Cracking the Gre Psychology)',
#   'Categories': 'mind central general counsel train educ subject graduat health prep bodi test profession book gre psycholog guid refer',
#   'Group': 'Book',
#   'SalesRank': 38783,
#   'TotalReviews': 17,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 16,
#   'ClusteringCoeff': 0.57},
#  '0918477638': {'Id': '1347',
#   'Title': 'Serenity of Heart: Bearing the Troubles of This Life',
#   'Categories': 'general subject religion spiritu catholic christian live book inspir',
#   'Group': 'Book',
#   'SalesRank': 1334103,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0762708085': {'Id': '1348',
#   'Title': 'Fun with the Family in Michigan: Hundreds of Ideas for Day Trips with the Kids',
#   'Categories': 'general subject specialti michigan famili unit state amazon com book midwest region travel store categori',
#   'Group': 'Book',
#   'SalesRank': 692681,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 3,
#   'ClusteringCoeff': 0.0},
#  '0786868821': {'Id': '1349',
#   'Title': 'Cad: Confessions of a Toxic Bachelor',
#   'Categories': 'general specif entertain biographi strip subject academ comic group memoir humor journalist profession book novel women graphic',
#   'Group': 'Book',
#   'SalesRank': 247366,
#   'TotalReviews': 44,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  '0826314384': {'Id': '1351',
#   'Title': 'Tierra Amarilla: Stories of New Mexico : Cuentos De Nuevo Mexico (Paso Por Aqui)',
#   'Categories': 'short general subject literatur british stori unit spanish state world book thriller mysteri fiction',
#   'Group': 'Book',
#   'SalesRank': 920020,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '0811201511': {'Id': '1352',
#   'Title': 'ABC of Reading',
#   'Categories': 'general subject literatur singl author unit z state world poetri th book ezra centuri pound p fiction',
#   'Group': 'Book',
#   'SalesRank': 202498,
#   'TotalReviews': 14,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 9,
#   'ClusteringCoeff': 0.69},
#  '0893343218': {'Id': '1353',
#   'Title': 'Teachers Guide to Community Organization: Strategies for Parent, Teacher and Community Groups to Improve the Schools',
#   'Categories': 'general nonfict specif biographi educ subject russia group polici memoir pedagogi book women histori',
#   'Group': 'Book',
#   'SalesRank': 1898676,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '030680736X': {'Id': '1354',
#   'Title': 'Dr. Seuss & Mr. Geisel: A Biography',
#   'Categories': 'art general biographi subject literatur parent author dr famili popular seuss children memoir charact book guid',
#   'Group': 'Book',
#   'SalesRank': 97073,
#   'TotalReviews': 9,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0674008340': {'Id': '1355',
#   'Title': 'Black Rice: The African Origins of Rice Cultivation in the Americas',
#   'Categories': 'general nonfict subject african special group sociolog social book scienc american studi',
#   'Group': 'Book',
#   'SalesRank': 282005,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '0742512967': {'Id': '1356',
#   'Title': "American Heat: Ethical Problems With the United States' Response to Global Warming (Studies in Social, Political, and Legal Philosophy)",
#   'Categories': 'nonfict general subject conserv polit outdoor philosophi polici public govern natur environ book modern u',
#   'Group': 'Book',
#   'SalesRank': 846687,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.0},
#  '1558746609': {'Id': '1357',
#   'Title': "Chicken Soup for the Golfer's Soul: Stories of Insight, Inspiration and Laughter on the Links (Chicken Soup Series)",
#   'Categories': 'mind general subject religion jack format spiritu health author c help cd z bodi inspir book self sport canfield golf',
#   'Group': 'Book',
#   'SalesRank': 476325,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.7},
#  '0553214985': {'Id': '1358',
#   'Title': 'A Country Doctor (Bantam Classic)',
#   'Categories': 'general subject literatur classic book fiction',
#   'Group': 'Book',
#   'SalesRank': 437457,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.35},
#  '4333014786': {'Id': '1360',
#   'Title': 'Zen Seeds: Reflections of a Female Priest',
#   'Categories': 'nonfict general subject religion spiritu philosophi book buddhism',
#   'Group': 'Book',
#   'SalesRank': 512876,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0399146261': {'Id': '1361',
#   'Title': 'Three Complete Novels: Cold Fire, Hideaway, Key to Midnight',
#   'Categories': 'general subject author unit horror state z book dean koontz k',
#   'Group': 'Book',
#   'SalesRank': 157418,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.9},
#  '0306809389': {'Id': '1365',
#   'Title': 'The Duel for France, 1944: The Men and Battles That Changed the Fate of Europe',
#   'Categories': 'general militari ii germani franc subject western war world europ book histori',
#   'Group': 'Book',
#   'SalesRank': 575583,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0781724716': {'Id': '1367',
#   'Title': 'Child and Adolescent Clinical Psychopharmacology',
#   'Categories': 'mind general counsel subject specialti health bodi pediatr book psycholog psychopharmacolog medicin',
#   'Group': 'Book',
#   'SalesRank': 191671,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 4,
#   'ClusteringCoeff': 0.87},
#  '0803949677': {'Id': '1368',
#   'Title': 'The Power of Silence: Social and Pragmatic Perspectives (Language and Language Behavior)',
#   'Categories': 'general nonfict subject word sociolog social book communic scienc languag refer',
#   'Group': 'Book',
#   'SalesRank': 467756,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0822525771': {'Id': '1369',
#   'Title': "David's Story: A Book About Surgery (Meeting the Challenge)",
#   'Categories': 'general subject book age children',
#   'Group': 'Book',
#   'SalesRank': 1848183,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553214039': {'Id': '1370',
#   'Title': 'The Swiss Family Robinson (Bantam Classics)',
#   'Categories': 'adventur general subject literatur action classic book genr fiction',
#   'Group': 'Book',
#   'SalesRank': 1086094,
#   'TotalReviews': 52,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.9},
#  '0553298046': {'Id': '1371',
#   'Title': 'Specter of the Past (Star Wars: The Hand of Thrawn, Book One)',
#   'Categories': 'general subject media war seri fantasi book scienc star fiction',
#   'Group': 'Book',
#   'SalesRank': 18558,
#   'TotalReviews': 221,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 16,
#   'ClusteringCoeff': 0.47},
#  '0471625469': {'Id': '1372',
#   'Title': 'An Introduction to the Theory of Numbers',
#   'Categories': 'mathemat subject number technic profession book theori scienc pure',
#   'Group': 'Book',
#   'SalesRank': 263175,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.35},
#  '0312063261': {'Id': '1373',
#   'Title': "Dancing on Tisha B'av",
#   'Categories': 'subject literatur gay book lesbian fiction',
#   'Group': 'Book',
#   'SalesRank': 353629,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '8817125539': {'Id': '1374',
#   'Title': 'An Italian in America',
#   'Categories': 'general biographi subject memoir europ itali amazon com book travel store categori',
#   'Group': 'Book',
#   'SalesRank': 238275,
#   'TotalReviews': 14,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0531164659': {'Id': '1375',
#   'Title': 'High School Hazing: When Rites Become Wrongs (Single Title: Teen)',
#   'Categories': 'mind general subject health place peopl bodi social book scienc teen children',
#   'Group': 'Book',
#   'SalesRank': 431993,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 1,
#   'ClusteringCoeff': 0.0},
#  '1576751414': {'Id': '1376',
#   'Title': 'Be Your Own Brand: A Breakthrough Formula for Standing Out from the Crowd',
#   'Categories': 'secret busi leadership book self com offic advertis general subject person health life bodi sale store appli counsel success primer amazon mind biographi manag home help transform psycholog market invest',
#   'Group': 'Book',
#   'SalesRank': 141178,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 11,
#   'ClusteringCoeff': 0.77},
#  '0619016884': {'Id': '1377',
#   'Title': '70-220: MCSE Guide to Designing Microsoft Windows 2000 Security',
#   'Categories': 'system busi book central com offic general subject technolog internet project secur store window os cours oper comput amazon publish mcse digit cultur manag home exam certif microsoft',
#   'Group': 'Book',
#   'SalesRank': 148463,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.35},
#  '0740725300': {'Id': '1378',
#   'Title': 'Traveling Light 2003 Block Calendar: Releasing the Burdens You Were Never Intended to Bear; The',
#   'Categories': 'general subject religion max cultur author spiritu pop accessori l z card book format lucado note',
#   'Group': 'Book',
#   'SalesRank': 745630,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375503366': {'Id': '1379',
#   'Title': 'The Requiem Shark : A Novel',
#   'Categories': 'adventur general subject sea literatur histor book contemporari genr fiction',
#   'Group': 'Book',
#   'SalesRank': 816290,
#   'TotalReviews': 23,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '0914732218': {'Id': '1380',
#   'Title': 'AGHORA, At the Left Hand of God (Aghora)',
#   'Categories': 'general subject religion spiritu occult book buddhism',
#   'Group': 'Book',
#   'SalesRank': 62274,
#   'TotalReviews': 21,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.73},
#  '9812348174': {'Id': '1381',
#   'Title': 'Insight Compact Guide Ireland (Insight Compact Guides)',
#   'Categories': 'general insight subject pocket guidebook seri europ ireland amazon com book travel guid store categori',
#   'Group': 'Book',
#   'SalesRank': 1175363,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0632057718': {'Id': '1382',
#   'Title': "Architects' Data",
#   'Categories': 'general subject style type build technic profession book architectur refer',
#   'Group': 'Book',
#   'SalesRank': 365164,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 0.0},
#  '1876175087': {'Id': '1384',
#   'Title': "Che in Africa: Che Guevara's Congo Diary",
#   'Categories': 'congo america book caribbean academ notabl democrat spi general subject cuba z memoir militari che guevara africa leader histor histori indi biographi polit profession west republ peopl g',
#   'Group': 'Book',
#   'SalesRank': 836852,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1870775724': {'Id': '1388',
#   'Title': 'Creating a Music Website',
#   'Categories': 'general entertain subject etc web perform site composit music internet midi develop comput commerc book theori design mixer',
#   'Group': 'Book',
#   'SalesRank': 1046034,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0813521505': {'Id': '1389',
#   'Title': "Irrationality: Why We Don't Think Straight!",
#   'Categories': 'mind general counsel subject health behavior bodi cognit technic profession book scienc psycholog',
#   'Group': 'Book',
#   'SalesRank': 739364,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087840273X': {'Id': '1391',
#   'Title': 'Alif Baa: Introduction to Arabic Letters and Sounds',
#   'Categories': 'foreign general subject instruct linguist word book languag refer arab',
#   'Group': 'Book',
#   'SalesRank': 23006,
#   'TotalReviews': 24,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 8,
#   'ClusteringCoeff': 0.83},
#  '0395742129': {'Id': '1393',
#   'Title': 'A Turkey for Thanksgiving',
#   'Categories': 'general subject b bunt eve place illustr author peopl fiction z age book thanksgiv holiday children festiv',
#   'Group': 'Book',
#   'SalesRank': 273599,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 28,
#   'ClusteringCoeff': 0.68},
#  '0452284015': {'Id': '1394',
#   'Title': 'The Darwin Awards II : Unnatural Selection',
#   'Categories': 'general entertain subject essay humor book',
#   'Group': 'Book',
#   'SalesRank': 26591,
#   'TotalReviews': 31,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.86},
#  '0743407083': {'Id': '1395',
#   'Title': 'Grand Avenue',
#   'Categories': 'general joy subject literatur author f z book romanc field contemporari fiction',
#   'Group': 'Book',
#   'SalesRank': 177689,
#   'TotalReviews': 71,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 7,
#   'ClusteringCoeff': 0.86},
#  '0944386237': {'Id': '1396',
#   'Title': 'The Bible Interpreted in Dream Symbols',
#   'Categories': 'mind mental counsel general religion subject spiritu health mysteri controversi knowledg bodi occult unexplain book psycholog religi dream studi',
#   'Group': 'Book',
#   'SalesRank': 1598633,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1573801534': {'Id': '1397',
#   'Title': "Insiders' Guide to Yellowstone and Grand Teton",
#   'Categories': 'lodg yellowston seri insid state campground book com general subject guidebook wyom food park store unit amazon mountain categori west region travel',
#   'Group': 'Book',
#   'SalesRank': 944279,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0520203569': {'Id': '1401',
#   'Title': 'Early Modern Japan',
#   'Categories': 'subject japan book asia histori',
#   'Group': 'Book',
#   'SalesRank': 587569,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 5,
#   'ClusteringCoeff': 0.9},
#  '1878610473': {'Id': '1403',
#   'Title': 'Working in the Dark: Reflections of a Poet of the Barrio',
#   'Categories': 'art general biographi subject literatur author memoir book',
#   'Group': 'Book',
#   'SalesRank': 484620,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 6,
#   'ClusteringCoeff': 0.83},
#  '1864500069': {'Id': '1405',
#   'Title': 'Loney Planet Chicago City Map (City Maps Series)',
#   'Categories': 'region subject illinoi unit map state chicago amazon book com midwest atlas travel store refer categori',
#   'Group': 'Book',
#   'SalesRank': 554729,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 2,
#   'ClusteringCoeff': 1.0},
#  ...}

# %%
pd.DataFrame(books_meta_dict).head()
# Out:
#                                                    0827229534  \
# Id                                                          1
# Title                 Patterns of Preaching: A Sermon Sampler
# Categories  clergi sermon subject religion preach spiritu ...
# Group                                                    Book
# SalesRank                                              396585
#
#                                                    0738700797  \
# Id                                                          2
# Title                              Candlemas: Feast of Flames
# Categories  subject witchcraft earth religion spiritu base...
# Group                                                    Book
# SalesRank                                              168596
#
#                                                   0486287785  \
# Id                                                         3
# Title       World War II Allied Fighter Planes Trading Cards
# Categories      general hobbi subject craft home garden book
# Group                                                   Book
# SalesRank                                            1270652
#
#                                                    0842328327  \
# Id                                                          4
# Title       Life Application Bible Commentary: 1 and 2 Tim...
# Categories  spiritu translat commentari christian book gui...
# Group                                                    Book
# SalesRank                                              631289
#
#                                                    1577943082  \
# Id                                                          5
# Title         Prayers That Avail Much for Business: Executive
# Categories  subject religion spiritu busi christian live w...
# Group                                                    Book
# SalesRank                                              455160
#
#                                                    0486220125  \
# Id                                                          6
# Title       How the Other Half Lives: Studies Among the Te...
# Categories  art general nonfict jewish subject essay camer...
# Group                                                    Book
# SalesRank                                              188784
#
#                                                    0231118597  \
# Id                                                          8
# Title                                     Losing Matt Shepard
# Categories  nonfict general subject polit criminolog crimi...
# Group                                                    Book
# SalesRank                                              277409
#
#                                                    1859677800  \
# Id                                                          9
# Title       Making Bread: The Taste of Traditional Home-Ba...
# Categories             wine subject food bake book cook bread
# Group                                                    Book
# SalesRank                                              949166
#
#                                                    0375709363  \
# Id                                                         10
# Title                                  The Edward Said Reader
# Categories  nonfict general subject literatur anthropolog ...
# Group                                                    Book
# SalesRank                                              220379
#
#                                                    0871318237  ...  \
# Id                                                         11  ...
# Title       Resetting the Clock : Five Anti-Aging Hormones...  ...
# Categories  mind general subject specialti health unknown ...  ...
# Group                                                    Book  ...
# SalesRank                                              412962  ...
#
#                                        0552139432  \
# Id                                         548535
# Title                              Lost for Words
# Categories  general subject biographi memoir book
# Group                                        Book
# SalesRank                                       0
#
#                                                    B00006RGI2  \
# Id                                                     548537
# Title       Anyway: The Paradoxical Commandments: Finding ...
# Categories  religion specialti spiritu bargain outlet amaz...
# Group                                                    Book
# SalesRank                                                   0
#
#                                                    B000067JZT  \
# Id                                                     548538
# Title                                                Just Dog
# Categories  general nonfict literatur specialti bargain fi...
# Group                                                    Book
# SalesRank                                                   0
#
#                                                    B00008MNUJ  \
# Id                                                     548539
# Title       A Matter of Degrees: What Temperature Reveals ...
# Categories  subject specialti bargain physic natur thermod...
# Group                                                    Book
# SalesRank                                                   0
#
#                                                    0060537612  \
# Id                                                     548540
# Title       If You Take a Mouse Five-Book Set (If You Take...
# Categories  general subject literatur humor anim book chil...
# Group                                                    Book
# SalesRank                                                   0
#
#                                        9700507734  \
# Id                                         548541
# Title                    Para alcanzar el orgasmo
# Categories  mind general subject health bodi book
# Group                                        Book
# SalesRank                                       0
#
#                                           9627762644  \
# Id                                            548542
# Title       Starting a Hedge Fund : A US Perspective
# Categories          general subject busi book invest
# Group                                           Book
# SalesRank                                          0
#
#                                                    0970020503  \
# Id                                                     548543
# Title                  Facts Every Injured Worker Should Know
# Categories  general subject busi book law practic guid lab...
# Group                                                    Book
# SalesRank                                                   0
#
#                                                    1930519206  \
# Id                                                     548546
# Title                       Adobe Photoshop 6 VTC Training CD
# Categories  book com offic graphic subject photoshop inter...
# Group                                                    Book
# SalesRank                                                   0
#
#                                                    0879736836
# Id                                                     548549
# Title           Catholic Bioethics and the Gift of Human Life
# Categories  general nonfict subject religion spiritu catho...
# Group                                                    Book
# SalesRank                                                   0
#
# [5 rows x 393561 columns]

# %%
file = open("./resources/books_data.edgelist", 'rb')
books_copurchase = nx.read_weighted_edgelist(file)
file.close()
print(nx.info(books_copurchase))
# Out:
# Name:
# Type: Graph
# Number of nodes: 270347
# Number of edges: 741124
# Average degree:   5.4828

# %%
print("Your Purchased Book")
print("-----------------")
asin = '0873376129'

# Print out the features associates with the book

print("\nTitle = ", books_meta_dict[asin]['Title'])
print("ASIN = ", asin)
print("SalesRank = ", books_meta_dict[asin]['SalesRank'])
print("TotalReviews = ", books_meta_dict[asin]['TotalReviews'])
print("AvgRating = ", books_meta_dict[asin]['AvgRating'])
print("DegreeCentrality = ", books_meta_dict[asin]['DegreeCentrality'])
print("ClusteringCoeff = ", books_meta_dict[asin]['ClusteringCoeff'])
# Out:
# Your Purchased Book
# -----------------
#
# Title =  U.S. Immigration Made Easy (8th Edition)
# ASIN =  0873376129
# SalesRank =  770576
# TotalReviews =  9
# AvgRating =  4.0
# DegreeCentrality =  4
# ClusteringCoeff =  1.0

# %%
ego = nx.ego_graph(books_copurchase, asin, radius=1)
print(f"Ego Network for {books_meta_dict[asin]['Title']}",
      f"Nodes = {ego.number_of_nodes()}",
      f"Edges = {ego.number_of_edges()}",
      sep='\n')
# Out:
# Ego Network for U.S. Immigration Made Easy (8th Edition)
# Nodes = 5
# Edges = 10

# %%
# Draw the ego network
nx.draw(ego, with_labels=True)

# %%
# Create empty graph instance `trimmed_ego_net` using the `nx.Graph()`to represent the trimmed network
threshold = 0.5
trimmed_ego = nx.Graph()

# Iterate through the network, comparing each weight with threshold
for node1, node2, edge in ego.edges(data=True):
    if edge['weight'] >= threshold:
        trimmed_ego.add_edge(node1, node2,
                             weight=edge.values())

# Print the trimmed statistics
print('Trimmed Ego Network for:', books_meta_dict[asin]['Title'],
      "\n____________________\n",
      "\nThreshold=", threshold,
      "\nNodes =", trimmed_ego.number_of_nodes(),
      "\nEdges =", trimmed_ego.number_of_edges())

# Show the Altars available in the trimmed network
print("\nASINs in the trimmed network: \n", list(trimmed_ego))
# Out:
# Trimmed Ego Network for: U.S. Immigration Made Easy (8th Edition)
# ____________________
#
# Threshold= 0.5
# Nodes = 5
# Edges = 6
#
# ASINs in the trimmed network:
#  ['0873376129', '0873378989', '1572481617', '0314232087', '0761536280']

# %%
lst_neighbors = list(trimmed_ego)
print("Purchased Book")
print("--------------\n")
print("Title: ", books_meta_dict[asin]['Title'])


print("\nCustomers who bought this book, also bought:")
print("-------------------------------------------")
for nb_asin in lst_neighbors[1:]:
    print("\nAsin: ", nb_asin)
    print("Book Title: ", books_meta_dict[nb_asin]["Title"])
    print("Average Rating:", books_meta_dict[nb_asin]["AvgRating"])
    print("Number of Reviews: ", books_meta_dict[nb_asin]["TotalReviews"])
# Out:
# Purchased Book
# --------------
#
# Title:  U.S. Immigration Made Easy (8th Edition)
#
# Customers who bought this book, also bought:
# -------------------------------------------
#
# Asin:  0873378989
# Book Title:  How to Get a Green Card: Legal Ways to Stay in the U.S.A
# Average Rating: 3.0
# Number of Reviews:  7
#
# Asin:  1572481617
# Book Title:  USA Immigration Guide (USA Immigration Guide)
# Average Rating: 5.0
# Number of Reviews:  1
#
# Asin:  0314232087
# Book Title:  Immigration Law and Procedure in a Nutshell (Nutshell Series)
# Average Rating: 3.5
# Number of Reviews:  2
#
# Asin:  0761536280
# Book Title:  U.S. Immigration & Citizenship
# Average Rating: 5.0
# Number of Reviews:  4

# %%
def also_bought(asin):
    ego = nx.ego_graph(books_copurchase, asin, radius=1)
    # Create empty graph instance `trimmed_ego_net` using the `nx.Graph()`to represent the trimmed network
    threshold = 0.5
    trimmed_ego = nx.Graph()

    # Iterate through the network, comparing each weight with threshold
    for node1, node2, edge in ego.edges(data=True):
        if edge['weight'] >= threshold:
            trimmed_ego.add_edge(node1, node2,
                                 weight=edge.values())

    lst_neighbors = list(trimmed_ego)
    print("Purchased Book")
    print("--------------\n")
    print("Title: ", books_meta_dict[asin]['Title'])


    print("\nCustomers who bought this book, also bought:")
    print("-------------------------------------------")
    for nb_asin in lst_neighbors[1:]:
        print("\nAsin: ", nb_asin)
        print("Book Title: ", books_meta_dict[nb_asin]["Title"])
        print("Average Rating:", books_meta_dict[nb_asin]["AvgRating"])
        print("Number of Reviews: ", books_meta_dict[nb_asin]["TotalReviews"])
        
also_bought('1859677800')
# Out:
# ---------------------------------------------------------------------------
# NodeNotFound                              Traceback (most recent call last)
# <ipython-input-27-59e6f26b62af> in <module>
#      25         print("Number of Reviews: ", books_meta_dict[nb_asin]["TotalReviews"])
#      26
# ---> 27 also_bought('1859677800')
#
# <ipython-input-27-59e6f26b62af> in also_bought(asin)
#       1 def also_bought(asin):
# ----> 2     ego = nx.ego_graph(books_copurchase, asin, radius=1)
#       3     # Create empty graph instance `trimmed_ego_net` using the `nx.Graph()`to represent the trimmed network
#       4     threshold = 0.5
#       5     trimmed_ego = nx.Graph()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/generators/ego.py in ego_graph(G, n, radius, center, undirected, distance)
#      64                                               weight=distance)
#      65         else:
# ---> 66             sp = dict(nx.single_source_shortest_path_length(G, n, cutoff=radius))
#      67
#      68     H = G.subgraph(sp).copy()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      60     """
#      61     if source not in G:
# ---> 62         raise nx.NodeNotFound('Source {} is not in G'.format(source))
#      63     if cutoff is None:
#      64         cutoff = float('inf')
#
# NodeNotFound: Source 1859677800 is not in G

# %% [markdown]
# <img src ="./resources/social_network.jpg">

# %% [markdown]
# ## Additional Resources
#
# Awesome projects related to graph theory/networks (http://snap.stanford.edu/class/cs224w-2017/projects.html)
# Paper on recommender systems (http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.480.5927&rep=rep1&type=pdf)
# Another paper on recommender system (http://www.cs.cmu.edu/~jure/pubs/viral-tweb.pdf)
# More on clustering networks (http://pages.di.unipi.it/marino/cluster18.pdf)

# %% [markdown]
# # More NetworkX Practice

# %% [markdown]
# ## Graph Properties

# %%
G = nx.lollipop_graph(4, 6)

# %%
pathlengths = []

# %%
# This prints the source node and the dictionary of shortest lengths to various nodes
for v in G.nodes():
    spl = nx.single_source_shortest_path_length(G, v)
    print(f'{v} {spl}')
    for p in spl.values():
        pathlengths.append(p)

# %%
print(f"average shortest path length {sum(pathlengths)/len(pathlengths)}")

# %%
# histogram of path lengths
dist = {}
for p in pathlengths:
    if p in dist:
        dist[p] += 1
    else:
        dist[p] = 1
print("length #paths")
verts = dist.keys()
for d in sorted(verts):
    print(f'{d} {dist[d]}')

# %%
print(f"radius: {nx.radius(G)}")
print(f"diameter: {nx.diameter(G)}")
print(f"eccentricity: {nx.eccentricity(G)}")
print(f"center: {nx.center(G)}")
print(f"periphery: {nx.periphery(G)}")
print(f"density: {nx.density(G)}")

# %% [markdown]
# ## Path Graphing

# %%
g1 = nx.path_graph(8)

# %%
nx.draw(g1)

# %% [markdown]
# ## Four Implementations of the Same Graph

# %%
g5 = nx.grid_2d_graph(4, 4)  # 4x4 grid

# %%
pos = nx.spring_layout(g5, iterations=100)

# %%
nx.draw(g5, pos, font_size=8)

# %%
nx.draw(g5, pos, node_color='k', node_size=250, with_labels=False)

# %%
nx.draw(g5, pos, node_color='g', node_size=250, with_labels=False, width=6)

# %%
h5 = g5.to_directed()
nx.draw(h5, pos, node_color='b', node_size=250, with_labels=False)

# %% [markdown]
# ## Degrees

# %%
G = nx.gnp_random_graph(100, 0.02)

# %%
degree_sequence = sorted((d for n, d in G.degree()), reverse=True)

# %%
dmax = max(degree_sequence)

# %%
gcc = sorted(nx.connected_components(G), key=len, reverse=True)[0]

# %%
pos = nx.spring_layout(gcc)

# %%
nx.draw_networkx_nodes(gcc, pos, node_size=20)

# %%
nx.draw_networkx_edges(gcc, pos, alpha=0.4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-619663cda7bb> in <module>
# ----> 1 nx.draw_networkx_edges(gcc, pos, alpha=0.4)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, **kwds)
#     574
#     575     if edgelist is None:
# --> 576         edgelist = list(G.edges())
#     577
#     578     if not edgelist or len(edgelist) == 0:  # no edges!
#
# AttributeError: 'set' object has no attribute 'edges'

# %%
nx.draw_networkx_nodes(gcc, pos, node_size=20)
nx.draw_networkx_edges(gcc, pos, alpha=0.4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-0bf478355583> in <module>
#       1 nx.draw_networkx_nodes(gcc, pos, node_size=20)
# ----> 2 nx.draw_networkx_edges(gcc, pos, alpha=0.4)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, **kwds)
#     574
#     575     if edgelist is None:
# --> 576         edgelist = list(G.edges())
#     577
#     578     if not edgelist or len(edgelist) == 0:  # no edges!
#
# AttributeError: 'set' object has no attribute 'edges'

# %%
plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")
plt.axes([0.45,0.45,0.45,0.45])
plt.axis('off')
plt.show()

# %% [markdown]
# ## Edge Colormap

# %%
g2 = nx.star_graph(20)

# %%
pos = nx.spring_layout(g2)

# %%
nx.draw_networkx(g2, pos, node_color='#A0CBE2',
                 edge_color=range(20), width=4,
                 edge_cmap=plt.cm.Blues, with_labels=False)

# %% [markdown]
# ## Ego Graph

# %%
g3 = nx.generators.barabasi_albert_graph(1000, 2)

node_and_degree = dict(g3.degree())

largest_hub, degree = sorted(node_and_degree.items(), key=itemgetter(1))[-1]

hub_ego = nx.ego_graph(g3, largest_hub)

pos = nx.spring_layout(hub_ego)

nx.draw(hub_ego, pos, node_color='b', node_size=50, with_labels=False)
nx.draw_networkx_nodes(hub_ego, pos, nodelist=[largest_hub],
                       node_size=300, node_color='r')

# %% [markdown]
# ## GML Example: Football Teams

# %% [markdown]
# First, we download a ZIP file containing information about United States college football teams and extract the two text files contained within.

# %%
import io
import zipfile

import networkx
import requests

url = "http://www-personal.umich.edu/~mejn/netdata/football.zip"
response = requests.get(url)
content = io.BytesIO(response.content)
with zipfile.ZipFile(content) as zf:  # zipfile object
    txt = zf.read('football.txt').decode()  # read info file
    gml = zf.read('football.gml').decode()  # read gml data
    # throw away bogus first line with # from mejn files
    gml = gml.split('\n')[1:]

# %% [markdown]
# Then we parse the graph information from the GML file, convert that to a NetworkX graph object, then print the degree of each node in the graph, which represents the number of games played by each team.

# %%
import networkx as nx

fb = nx.parse_gml(gml) # parse gml data

print(txt)
# print degree for each team - number of games
for n, d in fb.degree():
    print(f'{n} {d}')
# Out:
# The file football.gml contains the network of American football games
# between Division IA colleges during regular season Fall 2000, as compiled
# by M. Girvan and M. Newman.  The nodes have values that indicate to which
# conferences they belong.  The values are as follows:
#
#   0 = Atlantic Coast
#   1 = Big East
#   2 = Big Ten
#   3 = Big Twelve
#   4 = Conference USA
#   5 = Independents
#   6 = Mid-American
#   7 = Mountain West
#   8 = Pacific Ten
#   9 = Southeastern
#  10 = Sun Belt
#  11 = Western Athletic
#
# If you make use of these data, please cite M. Girvan and M. E. J. Newman,
# Community structure in social and biological networks,
# Proc. Natl. Acad. Sci. USA 99, 7821-7826 (2002).
#
# Correction: Two edges were erroneously duplicated in this data set, and
# have been removed (21 SEP 2014)
#
# BrighamYoung 12
# FloridaState 12
# Iowa 12
# KansasState 12
# NewMexico 11
# TexasTech 12
# PennState 12
# SouthernCalifornia 12
# ArizonaState 11
# SanDiegoState 11
# Baylor 10
# NorthTexas 10
# NorthernIllinois 10
# Northwestern 11
# WesternMichigan 10
# Wisconsin 12
# Wyoming 11
# Auburn 11
# Akron 11
# VirginiaTech 11
# Alabama 11
# UCLA 11
# Arizona 11
# Utah 11
# ArkansasState 10
# NorthCarolinaState 11
# BallState 10
# Florida 11
# BoiseState 9
# BostonCollege 11
# WestVirginia 11
# BowlingGreenState 11
# Michigan 11
# Virginia 10
# Buffalo 11
# Syracuse 11
# CentralFlorida 8
# GeorgiaTech 11
# CentralMichigan 11
# Purdue 11
# Colorado 11
# ColoradoState 10
# Connecticut 7
# EasternMichigan 11
# EastCarolina 11
# Duke 11
# FresnoState 11
# OhioState 11
# Houston 11
# Rice 11
# Idaho 9
# Washington 11
# Kansas 10
# SouthernMethodist 12
# Kent 10
# Pittsburgh 11
# Kentucky 10
# Louisville 10
# LouisianaTech 10
# LouisianaMonroe 8
# Minnesota 11
# MiamiOhio 11
# Vanderbilt 11
# MiddleTennesseeState 9
# Illinois 11
# MississippiState 11
# Memphis 11
# Nevada 12
# Oregon 11
# NewMexicoState 11
# SouthCarolina 11
# Ohio 10
# IowaState 11
# SanJoseState 11
# Nebraska 11
# SouthernMississippi 10
# Tennessee 11
# Stanford 11
# WashingtonState 11
# Temple 11
# Navy 11
# TexasA&M 11
# NotreDame 11
# TexasElPaso 11
# Oklahoma 11
# Toledo 9
# Tulane 11
# Mississippi 11
# Tulsa 12
# NorthCarolina 11
# UtahState 9
# Army 11
# Cincinnati 11
# AirForce 10
# Rutgers 10
# Georgia 10
# LouisianaState 10
# LouisianaLafayette 8
# Texas 11
# Marshall 10
# MichiganState 11
# MiamiFlorida 10
# Missouri 10
# Clemson 10
# NevadaLasVegas 12
# WakeForest 10
# Indiana 11
# OklahomaState 10
# OregonState 10
# Maryland 11
# TexasChristian 11
# California 11
# AlabamaBirmingham 10
# Arkansas 10
# Hawaii 11

# %%
pos = nx.spring_layout(fb, iterations=100)

# %%
nx.draw(fb, pos, font_size=8)
